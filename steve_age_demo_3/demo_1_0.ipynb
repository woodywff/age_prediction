# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from preprocess import *

# preprocess_main()

# %%
open('abc')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-5d2086bf42bb> in <module>
# ----> 1 open('abc')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc'
