# %%
'''
This .py provides the process of check the compliance between the read data from .tfrec and the source data.
'''
from preprocess import *

NUM_EPOCHS = 10
SHAPE = np.load('./data_npy/mean_npy.npy').shape
BATCH_SIZE = 10



def decode(serialized_example):
    '''
    to decode data from .tfrec files
    '''
    features = tf.parse_single_example(
        serialized_example,
        features={
            'arr_raw':tf.FixedLenFeature([],tf.string),
            'label': tf.FixedLenFeature([],tf.float32),
            'id': tf.FixedLenFeature([],tf.int64),
        }
    )
    arr = tf.decode_raw(features['arr_raw'],tf.int64)
    arr = tf.reshape(arr,list(SHAPE))
    arr = tf.cast(arr,tf.float32) # to be compliance with the restriction of TypeError: 
                                  # Value passed to parameter 'input' has DataType int64 not in list of allowed values: 
                                  # float16, bfloat16, float32, float64
    label = features['label']
    sub_id = features['id']
    
    return arr,label,sub_id



def get_iterator(for_training=True,num_epochs=1):
    '''
    to generate iterators for training, validation and test datasets
    '''
    if not num_epochs:
        num_epochs = None
    root_dir = './'
    filename = os.path.join(root_dir,('training_data' if for_training else 'test_data')+'.tfrec')

    with tf.name_scope('input'):
        dataset = tf.data.TFRecordDataset(filename)
#         pdb.set_trace()
        dataset = dataset.map(decode)
        if for_training:
            dataset = dataset.repeat(num_epochs)
        dataset = dataset.batch(BATCH_SIZE)
        if for_training:
            train_iterator = dataset.make_one_shot_iterator()
            val_iterator = dataset.make_one_shot_iterator()
            iterators = [train_iterator,val_iterator]
        else:
            test_iterator = dataset.make_initializable_iterator()
            iterators = [test_iterator]

        
    return iterators

def try_equal(return_list,info_df):
    '''
    this function is going to print the data's information out when there's difference compared with the source data.
    return_list: [arr_batch,label_batch,id_batch, X]
    '''
    npy_dir='./data_npy/mean_subtracted/'
    decode_arr = return_list[0]
    decode_arr = decode_arr.astype(np.int64)

    decode_label = return_list[1]
    decode_label = np.round(decode_label,2)
    decode_id = return_list[2]
    decode_X = return_list[3]
    return_value = True

    for j in range(decode_id.shape[0]):
        d_a = decode_arr[j]
        d_l = decode_label[j]
        d_i = decode_id[j]

        d_x = decode_X[j]
        d_x = np.reshape(d_x,SHAPE)

        npy_filename = str(d_i) + '.npy'
        npy_path_filename = os.path.join(npy_dir,npy_filename)
#         print(npy_filename)

        try:
            arr_npy = np.load(npy_path_filename)
        except FileNotFoundError:
            print('No such file: ',npy_filename)
            continue
        label = round(info_df['age'][info_df['id']==d_i].values[0],2)
#         arr = arr_npy.astype(np.float32)
        arr=arr_npy

        if np.sum(d_x!=arr) != 0:
            print('d_x != arr')
            return_value = False


        if round(label-d_l,1)!=0 or np.sum(d_a!=arr)!=0:
            print(npy_path_filename)
            print('original label: ',label)
            print('extracted label: ',d_l)
            print('label == decode_label: ',round(label-d_l,2)==0)
            print('arr == decode_arr: ',np.sum(d_a!=arr))
            return_value = False
    #         break


        if d_i == 51075:
            print_sep()
#     print('try_equal finished.')
    return return_value




def tf_varify_training():
    '''
    This session checks the difference between data read from .tfrec files and their corresponding source data.
    for training, validation and test sets respectively
    '''
    iterators = get_iterator(num_epochs=NUM_EPOCHS)
    handle = tf.placeholder(tf.string,shape=[])
    iterator = tf.data.Iterator.from_string_handle(handle, iterators[0].output_types)
    arr_batch,label_batch,id_batch = iterator.get_next()


    X = tf.reshape(arr_batch, [-1]+list(SHAPE)+[1])

    info_df_training = pd.read_csv('./training.csv', sep=',',header=0)
    info_df_test = pd.read_csv('./test.csv', sep=',',header=0)

    with tf.Session() as sess:
        train_iterator_handle = sess.run(iterators[0].string_handle())
        val_iterator_handle = sess.run(iterators[1].string_handle())

        test_iterator = get_iterator(for_training=False)[0]
        test_iterator_handle = sess.run(test_iterator.string_handle())


        try:
            step = 0
            while True:
                start_time = time.time()
                return_list_training = sess.run([arr_batch,label_batch,id_batch, X], feed_dict={handle:train_iterator_handle})
                
#                 pdb.set_trace()
                if not try_equal(return_list_training,info_df_training):
                    print('Where am I: in return_list_training.')
                return_list_val = sess.run([arr_batch,label_batch,id_batch, X], feed_dict={handle:val_iterator_handle})
#                 pdb.set_trace()
                if not try_equal(return_list_val,info_df_training):
                    print('Where am I: in return_list_val.')
                duration = time.time() - start_time
#                     print(type(loss_value))
                if step % 100 == 0:
                    sess.run(test_iterator.initializer)
                    try:
                        while True:
                            return_list_test = sess.run([arr_batch,label_batch,id_batch, X], 
                                                       feed_dict={handle:test_iterator_handle})
                            
#                             pdb.set_trace()
                            print(return_list_test[2])
                            if not try_equal(return_list_test,info_df_test):
                                print('Where am I: in return_list_test.')
                    except tf.errors.OutOfRangeError:
                        print('test finished inside training')
                step += 1
        except tf.errors.OutOfRangeError:
            print('Done training for %d epochs, %d steps.' %(NUM_EPOCHS,step))
            
    return

def test_sess(input_iterator):
    '''
    main part of test process
    model_path: str; directry of the saved model which to be loaded, the best mse or the best person.
    '''
    handle = tf.placeholder(tf.string,shape=[])
    iterator = tf.data.Iterator.from_string_handle(handle, input_iterator.output_types)
    arr_batch,label_batch,id_batch = iterator.get_next()
    X = tf.reshape(arr_batch, [-1]+list(SHAPE)+[1])

    info_df_training = pd.read_csv('./training.csv', sep=',',header=0)
    info_df_test = pd.read_csv('./test.csv', sep=',',header=0)
    
    with tf.Session() as sess:
        test_iterator_handle = sess.run(input_iterator.string_handle())
        sess.run(input_iterator.initializer)
        try:
            while True:
#                 test_predicted_age,test_label = sess.run([predicted_age, label_batch],
#                                                 feed_dict={keep_prob:1.0,
#                                                            is_training_forBN:False,
#                                                           handle:test_iterator_handle})
                return_list_test = sess.run([arr_batch,label_batch,id_batch, X], 
                                                       feed_dict={handle:test_iterator_handle})
                print(return_list_test[2])
                if not try_equal(return_list_test,info_df_test):
                    print('Where am I: in return_list_test.')
        except tf.errors.OutOfRangeError:
            print('test finished outside training')
    return

def test_test_set():
    '''
    test process, test set as input
    model_path: str; directry of the saved model which to be loaded, the best mse or the best person.
    '''
    with tf.Graph().as_default():
        iterator = get_iterator(for_training=False)[0]
        test_sess(iterator)
    return


# tf_varify_training()
test_test_set()
# Out:
# [51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
# [51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
# [50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
# [51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
# [51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
# [50707 51129 50446 50113 50117 51051 51142]
# test finished outside training

# %%
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
---------------------------------------- - ----------------------------------------
[51127 51489 50169 51567 51483 51311 50572 50267 50701 50777]
[51086 50039 51131 50333 50691 50470 50197 51192 51251 51263]
[50352 50466 51049 51305 50371 51139 51275 50809 50037 50454]
[51255 50362 50733 50059 51334 50427 51096 50381 50391 50347]
[51347 51091 50776 50265 50449 50451 50262 50773 50727 50106]
[50707 51129 50446 50113 50117 51051 51142]
test finished inside training
Done training for 10 epochs, 514 steps.

# %%
# !python model_woody.py --num_epochs=5 --MIN_VAL_MSE=10000 --MAX_VAL_PERSON=0.1 | tee ./log/training_woody_try.log
# Out:
# 2019-04-21 23:18:33.329811: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-21 23:18:33.412355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-04-21 23:18:33.412733: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.38GiB
# 2019-04-21 23:18:33.412746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:18:33.587516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:18:33.587551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:18:33.587558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:18:33.587718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10034 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:19:14.595268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:19:14.595319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:19:14.595348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:19:14.595354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:19:14.595472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10034 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:19:17.839382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:19:17.839435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:19:17.839442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:19:17.839447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:19:17.839567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10034 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:19:20.907092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:19:20.907130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:19:20.907135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:19:20.907139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:19:20.907235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10034 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:19:21.812287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:19:21.812325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:19:21.812331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:19:21.812335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:19:21.812442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10034 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 6012221.50, training_acc = 0.17
#                              val_loss(test_loss) = 7732320.50, val_acc(test_acc) = -0.21
# Step 100: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 743.50, training_acc = 0.44
#                              val_loss(test_loss) = 393.67, val_acc(test_acc) = 0.23
# best mse model: mse of validation set = 393.67, step = 100
# best person correlation model: person correlation coefficient of validation set = 0.23, step = 100
# Step 200: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 440.17, training_acc = 0.26
#                              val_loss(test_loss) = 274.92, val_acc(test_acc) = 0.31
# best mse model: mse of validation set = 274.92, step = 200
# best mse model saved successfully.
# best person correlation model: person correlation coefficient of validation set = 0.31, step = 200
# best person correlation model saved successfully.
# Done training for 5 epochs, 257 steps.
# time elapsed: 0 days, 0 hours, 0 mins, 40.364 secs.
# ./img/training_return_list_woody.npy exists already. Cover it...
# l1_conv3d/Relu   [None, 67, 67, 67, 16]
# l1_conv3d/max_pool3d   [None, 34, 34, 34, 16]
# l2_conv3d/Relu   [None, 34, 34, 34, 32]
# l2_conv3d/max_pool3d   [None, 17, 17, 17, 32]
# l3_conv3d/Relu   [None, 17, 17, 17, 64]
# l3_conv3d/max_pool3d   [None, 9, 9, 9, 64]
# l4_conv3d/Relu   [None, 9, 9, 9, 64]
# l4_conv3d/max_pool3d   [None, 5, 5, 5, 64]
# l5_conv3d/Relu   [None, 5, 5, 5, 64]
# l5_conv3d/max_pool3d   [None, 3, 3, 3, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# Model loaded successfully.
# test_loss = 307.49, test_accuracy = 0.29.
# Figure(640x480)
# l1_conv3d/Relu   [None, 67, 67, 67, 16]
# l1_conv3d/max_pool3d   [None, 34, 34, 34, 16]
# l2_conv3d/Relu   [None, 34, 34, 34, 32]
# l2_conv3d/max_pool3d   [None, 17, 17, 17, 32]
# l3_conv3d/Relu   [None, 17, 17, 17, 64]
# l3_conv3d/max_pool3d   [None, 9, 9, 9, 64]
# l4_conv3d/Relu   [None, 9, 9, 9, 64]
# l4_conv3d/max_pool3d   [None, 5, 5, 5, 64]
# l5_conv3d/Relu   [None, 5, 5, 5, 64]
# l5_conv3d/max_pool3d   [None, 3, 3, 3, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# Model loaded successfully.
# test_loss = 307.49, test_accuracy = 0.29.
# Figure(640x480)
# l1_conv3d/Relu   [None, 67, 67, 67, 16]
# l1_conv3d/max_pool3d   [None, 34, 34, 34, 16]
# l2_conv3d/Relu   [None, 34, 34, 34, 32]
# l2_conv3d/max_pool3d   [None, 17, 17, 17, 32]
# l3_conv3d/Relu   [None, 17, 17, 17, 64]
# l3_conv3d/max_pool3d   [None, 9, 9, 9, 64]
# l4_conv3d/Relu   [None, 9, 9, 9, 64]
# l4_conv3d/max_pool3d   [None, 5, 5, 5, 64]
# l5_conv3d/Relu   [None, 5, 5, 5, 64]
# l5_conv3d/max_pool3d   [None, 3, 3, 3, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# Model loaded successfully.
# test_loss = 274.92, test_accuracy = 0.31.
# Figure(640x480)
# l1_conv3d/Relu   [None, 67, 67, 67, 16]
# l1_conv3d/max_pool3d   [None, 34, 34, 34, 16]
# l2_conv3d/Relu   [None, 34, 34, 34, 32]
# l2_conv3d/max_pool3d   [None, 17, 17, 17, 32]
# l3_conv3d/Relu   [None, 17, 17, 17, 64]
# l3_conv3d/max_pool3d   [None, 9, 9, 9, 64]
# l4_conv3d/Relu   [None, 9, 9, 9, 64]
# l4_conv3d/max_pool3d   [None, 5, 5, 5, 64]
# l5_conv3d/Relu   [None, 5, 5, 5, 64]
# l5_conv3d/max_pool3d   [None, 3, 3, 3, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# Model loaded successfully.
# test_loss = 274.92, test_accuracy = 0.31.
# Figure(640x480)

# %%
# !python model_zach.py --num_epochs=10 --MIN_VAL_MSE=100000 --MAX_VAL_PERSON=-10 | tee ./log/training_zach_try.log
# Out:
# 2019-04-21 23:36:36.572779: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-21 23:36:36.660266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-04-21 23:36:36.660629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.39GiB
# 2019-04-21 23:36:36.660642: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:36:36.833984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:36:36.834019: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:36:36.834026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:36:36.834174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10044 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:37:37.390232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:37:37.390282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:37:37.390290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:37:37.390310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:37:37.390415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10044 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:37:39.688487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:37:39.688523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:37:39.688530: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:37:39.688534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:37:39.688614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10044 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:37:41.901336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:37:41.901373: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:37:41.901380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:37:41.901385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:37:41.901468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10044 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-04-21 23:37:42.478439: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-04-21 23:37:42.478476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-04-21 23:37:42.478483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-04-21 23:37:42.478487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-04-21 23:37:42.478573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10044 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# MaxPool3D   [None, 34, 34, 34, 8]
# MaxPool3D_1   [None, 17, 17, 17, 16]
# MaxPool3D_2   [None, 9, 9, 9, 32]
# MaxPool3D_3   [None, 5, 5, 5, 64]
# MaxPool3D_4   [None, 3, 3, 3, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# Let's get started to train!
# Step 0: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 36738.46, training_acc = 0.18
#                              val_loss(test_loss) = 49103.04, val_acc(test_acc) = 0.18
# best mse model: mse of validation set = 49103.04, step = 0
# best person correlation model: person correlation coefficient of validation set = 0.18, step = 0
# Step 100: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 89690.65, training_acc = 0.42
#                              val_loss(test_loss) = 15574.07, val_acc(test_acc) = 0.17
# best mse model: mse of validation set = 15574.07, step = 100
# Step 200: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 478.59, training_acc = 0.17
#                              val_loss(test_loss) = 3360.17, val_acc(test_acc) = -0.02
# best mse model: mse of validation set = 3360.17, step = 200
# best mse model saved successfully.
# Step 300: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 4299.81, training_acc = 0.35
#                              val_loss(test_loss) = 8661.69, val_acc(test_acc) = 0.17
# Step 400: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 20596.22, training_acc = 0.39
#                              val_loss(test_loss) = 19158.64, val_acc(test_acc) = 0.23
# best person correlation model: person correlation coefficient of validation set = 0.23, step = 400
# best person correlation model saved successfully.
# Step 500: (loss func: MSE, acc func: Pearson correlation coefficient)
#                              training_loss = 824.28, training_acc = 0.30
#                              val_loss(test_loss) = 2037.37, val_acc(test_acc) = 0.07
# best mse model: mse of validation set = 2037.37, step = 500
# best mse model saved successfully.
# Done training for 10 epochs, 514 steps.
# time elapsed: 0 days, 0 hours, 1 mins, 0.1 secs.
# ./img/training_return_list_zach.npy exists already. Cover it...
# MaxPool3D   [None, 34, 34, 34, 8]
# MaxPool3D_1   [None, 17, 17, 17, 16]
# MaxPool3D_2   [None, 9, 9, 9, 32]
# MaxPool3D_3   [None, 5, 5, 5, 64]
# MaxPool3D_4   [None, 3, 3, 3, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# Model loaded successfully.
# test_loss = 5982.24, test_accuracy = 0.10.
# Figure(640x480)
# MaxPool3D   [None, 34, 34, 34, 8]
# MaxPool3D_1   [None, 17, 17, 17, 16]
# MaxPool3D_2   [None, 9, 9, 9, 32]
# MaxPool3D_3   [None, 5, 5, 5, 64]
# MaxPool3D_4   [None, 3, 3, 3, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# Model loaded successfully.
# test_loss = 21528.36, test_accuracy = 0.25.
# Figure(640x480)
# MaxPool3D   [None, 34, 34, 34, 8]
# MaxPool3D_1   [None, 17, 17, 17, 16]
# MaxPool3D_2   [None, 9, 9, 9, 32]
# MaxPool3D_3   [None, 5, 5, 5, 64]
# MaxPool3D_4   [None, 3, 3, 3, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# Model loaded successfully.
# test_loss = 2037.37, test_accuracy = 0.07.
# Figure(640x480)
# MaxPool3D   [None, 34, 34, 34, 8]
# MaxPool3D_1   [None, 17, 17, 17, 16]
# MaxPool3D_2   [None, 9, 9, 9, 32]
# MaxPool3D_3   [None, 5, 5, 5, 64]
# MaxPool3D_4   [None, 3, 3, 3, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# Model loaded successfully.
# test_loss = 19158.64, test_accuracy = 0.23.
# Figure(640x480)
