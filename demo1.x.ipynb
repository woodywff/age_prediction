# %% [markdown]
# Replication of Ruyi's code.
#
# Dataset: IXI
#
# 10% for test, 90% for training. (Option: k-folds cross validation, not implemented yet.)
#
# Using 3D-CNN model code of my own

# %%
# main:
# !python preprocess.py

# %%
# !python demo_1_1.py --num_epochs=500
# !python demo_1_2.py --num_epochs=500 --MIN_TEST_LOSS=1000.0
# Out:
# l1_conv3d/Relu   [None, 130, 130, 110, 16]
# l1_conv3d/max_pool3d   [None, 65, 65, 55, 16]
# l2_conv3d/Relu   [None, 65, 65, 55, 32]
# l2_conv3d/max_pool3d   [None, 33, 33, 28, 32]
# l3_conv3d/Relu   [None, 33, 33, 28, 64]
# l3_conv3d/max_pool3d   [None, 17, 17, 14, 64]
# l4_conv3d/Relu   [None, 17, 17, 14, 64]
# l4_conv3d/max_pool3d   [None, 9, 9, 7, 64]
# l5_conv3d/Relu   [None, 9, 9, 7, 64]
# l5_conv3d/max_pool3d   [None, 5, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-07 11:10:53.139948: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-07 11:10:53.235688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-07 11:10:53.236056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.35GiB
# 2019-03-07 11:10:53.236069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-07 11:10:53.405864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-07 11:10:53.405893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-07 11:10:53.405900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-07 11:10:53.406060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10003 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: training_loss = 497620.16 (3.157 sec)
#  (val_loss)test_loss = 405669.88
# Step 100: training_loss = 2440.14 (0.739 sec)
#  (val_loss)test_loss = 2806.39
# Step 200: training_loss = 3186.15 (0.752 sec)
#  (val_loss)test_loss = 2519.49
# Step 300: training_loss = 2804.79 (0.747 sec)
#  (val_loss)test_loss = 2388.52
# Step 400: training_loss = 3304.85 (0.746 sec)
#  (val_loss)test_loss = 2300.83
# Step 500: training_loss = 2253.76 (0.748 sec)
#  (val_loss)test_loss = 2212.07
# Step 600: training_loss = 2551.75 (0.746 sec)
#  (val_loss)test_loss = 2131.48
# Step 700: training_loss = 2623.17 (0.741 sec)
#  (val_loss)test_loss = 2095.30
# Step 800: training_loss = 1960.00 (0.746 sec)
#  (val_loss)test_loss = 2013.45
# Step 900: training_loss = 3072.64 (0.747 sec)
#  (val_loss)test_loss = 1976.48
# Step 1000: training_loss = 2044.34 (0.748 sec)
#  (val_loss)test_loss = 1882.16
# Step 1100: training_loss = 2421.95 (0.745 sec)
#  (val_loss)test_loss = 1795.79
# Step 1200: training_loss = 1074.67 (0.760 sec)
#  (val_loss)test_loss = 1744.87
# Step 1300: training_loss = 1626.67 (0.741 sec)
#  (val_loss)test_loss = 1666.82
# Step 1400: training_loss = 1729.46 (0.742 sec)
#  (val_loss)test_loss = 1591.90
# Step 1500: training_loss = 996.36 (0.757 sec)
#  (val_loss)test_loss = 1547.41
# Step 1600: training_loss = 1325.08 (0.748 sec)
#  (val_loss)test_loss = 1474.00
# Step 1700: training_loss = 1856.25 (0.752 sec)
#  (val_loss)test_loss = 1412.76
# Step 1800: training_loss = 1682.84 (0.744 sec)
#  (val_loss)test_loss = 1366.48
# Step 1900: training_loss = 1304.39 (0.751 sec)
#  (val_loss)test_loss = 1370.77
# Step 2000: training_loss = 1656.15 (0.747 sec)
#  (val_loss)test_loss = 1233.18
# Step 2100: training_loss = 1359.11 (0.742 sec)
#  (val_loss)test_loss = 1258.93
# Step 2200: training_loss = 1507.47 (0.742 sec)
#  (val_loss)test_loss = 1161.48
# Step 2300: training_loss = 1062.77 (0.746 sec)
#  (val_loss)test_loss = 1063.24
# Step 2400: training_loss = 935.80 (0.754 sec)
#  (val_loss)test_loss = 1062.76
# Step 2500: training_loss = 932.90 (0.750 sec)
#  (val_loss)test_loss = 1032.02
# Step 2600: training_loss = 922.64 (0.752 sec)
#  (val_loss)test_loss = 1020.14
# Step 2700: training_loss = 825.35 (0.747 sec)
#  (val_loss)test_loss = 907.05
# Step 2800: training_loss = 1007.84 (0.753 sec)
#  (val_loss)test_loss = 869.74
# Step 2900: training_loss = 1050.52 (0.748 sec)
#  (val_loss)test_loss = 770.52
# Step 3000: training_loss = 570.66 (0.744 sec)
#  (val_loss)test_loss = 758.96
# Step 3100: training_loss = 271.51 (0.739 sec)
#  (val_loss)test_loss = 728.04
# Step 3200: training_loss = 622.10 (0.752 sec)
#  (val_loss)test_loss = 679.15
# Step 3300: training_loss = 699.97 (0.750 sec)
#  (val_loss)test_loss = 624.31
# Step 3400: training_loss = 891.19 (0.757 sec)
#  (val_loss)test_loss = 648.02
# Step 3500: training_loss = 727.03 (0.747 sec)
#  (val_loss)test_loss = 567.33
# Step 3600: training_loss = 546.59 (0.742 sec)
#  (val_loss)test_loss = 562.35
# Step 3700: training_loss = 702.26 (0.747 sec)
#  (val_loss)test_loss = 517.18
# Step 3800: training_loss = 521.14 (0.759 sec)
#  (val_loss)test_loss = 475.52
# best shot model: test_loss = 475.52, step = 3800
# model saved successfully.
# Step 3900: training_loss = 381.07 (0.748 sec)
#  (val_loss)test_loss = 463.75
# best shot model: test_loss = 463.75, step = 3900
# model saved successfully.
# Step 4000: training_loss = 766.10 (0.746 sec)
#  (val_loss)test_loss = 454.37
# best shot model: test_loss = 454.37, step = 4000
# model saved successfully.
# Step 4100: training_loss = 475.96 (0.746 sec)
#  (val_loss)test_loss = 437.46
# best shot model: test_loss = 437.46, step = 4100
# model saved successfully.
# Step 4200: training_loss = 410.64 (0.747 sec)
#  (val_loss)test_loss = 422.88
# best shot model: test_loss = 422.88, step = 4200
# model saved successfully.
# Step 4300: training_loss = 395.31 (0.746 sec)
#  (val_loss)test_loss = 408.46
# best shot model: test_loss = 408.46, step = 4300
# model saved successfully.
# Step 4400: training_loss = 221.92 (0.746 sec)
#  (val_loss)test_loss = 385.88
# best shot model: test_loss = 385.88, step = 4400
# model saved successfully.
# Step 4500: training_loss = 337.91 (0.745 sec)
#  (val_loss)test_loss = 361.98
# best shot model: test_loss = 361.98, step = 4500
# model saved successfully.
# Step 4600: training_loss = 286.04 (0.755 sec)
#  (val_loss)test_loss = 378.70
# Step 4700: training_loss = 316.01 (0.748 sec)
#  (val_loss)test_loss = 367.53
# Step 4800: training_loss = 238.79 (0.746 sec)
#  (val_loss)test_loss = 347.77
# best shot model: test_loss = 347.77, step = 4800
# model saved successfully.
# Step 4900: training_loss = 460.01 (0.741 sec)
#  (val_loss)test_loss = 346.08
# best shot model: test_loss = 346.08, step = 4900
# model saved successfully.
# Step 5000: training_loss = 646.72 (0.749 sec)
#  (val_loss)test_loss = 339.86
# best shot model: test_loss = 339.86, step = 5000
# model saved successfully.
# Step 5100: training_loss = 224.89 (0.746 sec)
#  (val_loss)test_loss = 325.90
# best shot model: test_loss = 325.90, step = 5100
# model saved successfully.
# Step 5200: training_loss = 413.60 (0.747 sec)
#  (val_loss)test_loss = 346.03
# Step 5300: training_loss = 205.03 (0.747 sec)
#  (val_loss)test_loss = 330.95
# Step 5400: training_loss = 109.30 (0.747 sec)
#  (val_loss)test_loss = 327.87
# Step 5500: training_loss = 296.31 (0.746 sec)
#  (val_loss)test_loss = 317.67
# best shot model: test_loss = 317.67, step = 5500
# model saved successfully.
# Step 5600: training_loss = 128.13 (0.755 sec)
#  (val_loss)test_loss = 339.98
# Step 5700: training_loss = 532.13 (0.740 sec)
#  (val_loss)test_loss = 329.49
# Step 5800: training_loss = 310.48 (0.746 sec)
#  (val_loss)test_loss = 319.14
# Step 5900: training_loss = 316.31 (0.740 sec)
#  (val_loss)test_loss = 334.56
# Step 6000: training_loss = 233.28 (0.749 sec)
#  (val_loss)test_loss = 317.97
# Step 6100: training_loss = 149.93 (0.775 sec)
#  (val_loss)test_loss = 316.02
# best shot model: test_loss = 316.02, step = 6100
# model saved successfully.
# Step 6200: training_loss = 471.01 (0.750 sec)
#  (val_loss)test_loss = 317.58
# Step 6300: training_loss = 300.18 (0.749 sec)
#  (val_loss)test_loss = 317.43
# Step 6400: training_loss = 206.39 (0.763 sec)
#  (val_loss)test_loss = 323.86
# Step 6500: training_loss = 188.69 (0.758 sec)
#  (val_loss)test_loss = 321.56
# Step 6600: training_loss = 286.90 (0.772 sec)
#  (val_loss)test_loss = 310.36
# best shot model: test_loss = 310.36, step = 6600
# model saved successfully.
# Step 6700: training_loss = 384.69 (0.760 sec)
#  (val_loss)test_loss = 317.10
# Step 6800: training_loss = 232.61 (0.751 sec)
#  (val_loss)test_loss = 318.35
# Step 6900: training_loss = 389.88 (0.748 sec)
#  (val_loss)test_loss = 311.66
# Step 7000: training_loss = 378.10 (0.754 sec)
#  (val_loss)test_loss = 313.34
# Step 7100: training_loss = 393.65 (0.751 sec)
#  (val_loss)test_loss = 320.28
# Step 7200: training_loss = 299.04 (0.761 sec)
#  (val_loss)test_loss = 310.40
# Step 7300: training_loss = 326.95 (0.751 sec)
#  (val_loss)test_loss = 309.50
# best shot model: test_loss = 309.50, step = 7300
# model saved successfully.
# Step 7400: training_loss = 244.10 (0.749 sec)
#  (val_loss)test_loss = 321.61
# Step 7500: training_loss = 270.50 (0.750 sec)
#  (val_loss)test_loss = 322.22
# Step 7600: training_loss = 337.30 (0.748 sec)
#  (val_loss)test_loss = 318.14
# Step 7700: training_loss = 355.70 (0.748 sec)
#  (val_loss)test_loss = 313.47
# Step 7800: training_loss = 296.41 (0.750 sec)
#  (val_loss)test_loss = 310.63
# Step 7900: training_loss = 195.60 (0.750 sec)
#  (val_loss)test_loss = 306.63
# best shot model: test_loss = 306.63, step = 7900
# model saved successfully.
# Step 8000: training_loss = 212.29 (0.753 sec)
#  (val_loss)test_loss = 310.31
# Step 8100: training_loss = 354.22 (0.751 sec)
#  (val_loss)test_loss = 310.53
# Step 8200: training_loss = 253.06 (0.749 sec)
#  (val_loss)test_loss = 307.62
# Step 8300: training_loss = 277.01 (0.751 sec)
#  (val_loss)test_loss = 304.97
# best shot model: test_loss = 304.97, step = 8300
# model saved successfully.
# Step 8400: training_loss = 296.43 (0.753 sec)
#  (val_loss)test_loss = 309.77
# Step 8500: training_loss = 260.02 (0.746 sec)
#  (val_loss)test_loss = 323.29
# Step 8600: training_loss = 373.52 (0.752 sec)
#  (val_loss)test_loss = 308.26
# Step 8700: training_loss = 346.59 (0.749 sec)
#  (val_loss)test_loss = 331.23
# Step 8800: training_loss = 407.88 (0.753 sec)
#  (val_loss)test_loss = 313.40
# Step 8900: training_loss = 267.55 (0.752 sec)
#  (val_loss)test_loss = 308.16
# Step 9000: training_loss = 414.35 (0.753 sec)
#  (val_loss)test_loss = 315.48
# Step 9100: training_loss = 310.41 (0.752 sec)
#  (val_loss)test_loss = 309.80
# Step 9200: training_loss = 280.04 (0.747 sec)
#  (val_loss)test_loss = 313.63
# Step 9300: training_loss = 377.35 (0.745 sec)
#  (val_loss)test_loss = 304.83
# best shot model: test_loss = 304.83, step = 9300
# model saved successfully.
# Step 9400: training_loss = 318.10 (0.752 sec)
#  (val_loss)test_loss = 325.18
# Step 9500: training_loss = 378.39 (0.752 sec)
#  (val_loss)test_loss = 313.95
# Step 9600: training_loss = 199.32 (0.748 sec)
#  (val_loss)test_loss = 306.65
# Step 9700: training_loss = 159.42 (0.747 sec)
#  (val_loss)test_loss = 316.97
# Step 9800: training_loss = 308.45 (0.746 sec)
#  (val_loss)test_loss = 303.44
# best shot model: test_loss = 303.44, step = 9800
# model saved successfully.
# Step 9900: training_loss = 237.33 (0.746 sec)
#  (val_loss)test_loss = 302.58
# best shot model: test_loss = 302.58, step = 9900
# model saved successfully.
# Step 10000: training_loss = 233.27 (0.749 sec)
#  (val_loss)test_loss = 303.67
# Step 10100: training_loss = 257.32 (0.749 sec)
#  (val_loss)test_loss = 308.74
# Step 10200: training_loss = 389.62 (0.750 sec)
#  (val_loss)test_loss = 309.18
# Step 10300: training_loss = 531.36 (0.745 sec)
#  (val_loss)test_loss = 302.95
# Step 10400: training_loss = 295.36 (0.756 sec)
#  (val_loss)test_loss = 316.81
# Step 10500: training_loss = 359.16 (0.753 sec)
#  (val_loss)test_loss = 312.96
# Step 10600: training_loss = 211.26 (0.748 sec)
#  (val_loss)test_loss = 313.95
# Step 10700: training_loss = 92.54 (0.746 sec)
#  (val_loss)test_loss = 309.99
# Step 10800: training_loss = 288.74 (0.747 sec)
#  (val_loss)test_loss = 307.17
# Step 10900: training_loss = 162.44 (0.751 sec)
#  (val_loss)test_loss = 307.05
# Step 11000: training_loss = 427.63 (0.747 sec)
#  (val_loss)test_loss = 304.28
# Step 11100: training_loss = 291.92 (0.741 sec)
#  (val_loss)test_loss = 311.76
# Step 11200: training_loss = 269.69 (0.746 sec)
#  (val_loss)test_loss = 305.80
# Step 11300: training_loss = 223.60 (0.747 sec)
#  (val_loss)test_loss = 309.53
# Step 11400: training_loss = 134.20 (0.752 sec)
#  (val_loss)test_loss = 303.13
# Step 11500: training_loss = 419.63 (0.748 sec)
#  (val_loss)test_loss = 304.23
# Step 11600: training_loss = 288.95 (0.751 sec)
#  (val_loss)test_loss = 309.46
# Step 11700: training_loss = 212.17 (0.750 sec)
#  (val_loss)test_loss = 306.93
# Step 11800: training_loss = 155.47 (0.754 sec)
#  (val_loss)test_loss = 306.02
# Step 11900: training_loss = 278.04 (0.750 sec)
#  (val_loss)test_loss = 303.65
# Step 12000: training_loss = 369.74 (0.749 sec)
#  (val_loss)test_loss = 305.49
# Step 12100: training_loss = 192.44 (0.748 sec)
#  (val_loss)test_loss = 306.40
# Step 12200: training_loss = 393.06 (0.748 sec)
#  (val_loss)test_loss = 304.05
# Step 12300: training_loss = 343.06 (0.750 sec)
#  (val_loss)test_loss = 310.43
# Step 12400: training_loss = 389.23 (0.746 sec)
#  (val_loss)test_loss = 313.03
# Step 12500: training_loss = 294.57 (0.754 sec)
#  (val_loss)test_loss = 312.84
# Step 12600: training_loss = 292.39 (0.764 sec)
#  (val_loss)test_loss = 308.13
# Step 12700: training_loss = 233.86 (0.750 sec)
#  (val_loss)test_loss = 311.46
# Step 12800: training_loss = 225.90 (0.746 sec)
#  (val_loss)test_loss = 304.20
# Step 12900: training_loss = 323.29 (0.751 sec)
#  (val_loss)test_loss = 307.11
# Step 13000: training_loss = 356.43 (0.748 sec)
#  (val_loss)test_loss = 306.81
# Step 13100: training_loss = 290.31 (0.748 sec)
#  (val_loss)test_loss = 324.46
# Step 13200: training_loss = 198.75 (0.755 sec)
#  (val_loss)test_loss = 317.27
# Step 13300: training_loss = 205.20 (0.749 sec)
#  (val_loss)test_loss = 301.78
# best shot model: test_loss = 301.78, step = 13300
# model saved successfully.
# Step 13400: training_loss = 353.16 (0.752 sec)
#  (val_loss)test_loss = 307.04
# Step 13500: training_loss = 231.94 (0.754 sec)
#  (val_loss)test_loss = 303.69
# Step 13600: training_loss = 293.09 (0.751 sec)
#  (val_loss)test_loss = 303.99
# Step 13700: training_loss = 279.12 (0.748 sec)
#  (val_loss)test_loss = 302.65
# Step 13800: training_loss = 256.33 (0.750 sec)
#  (val_loss)test_loss = 308.41
# Step 13900: training_loss = 370.73 (0.746 sec)
#  (val_loss)test_loss = 315.15
# Step 14000: training_loss = 348.25 (0.751 sec)
#  (val_loss)test_loss = 302.98
# Step 14100: training_loss = 411.34 (0.744 sec)
#  (val_loss)test_loss = 307.56
# Step 14200: training_loss = 258.95 (0.748 sec)
#  (val_loss)test_loss = 302.25
# Step 14300: training_loss = 411.42 (0.748 sec)
#  (val_loss)test_loss = 309.05
# Step 14400: training_loss = 303.43 (0.750 sec)
#  (val_loss)test_loss = 304.77
# Step 14500: training_loss = 298.56 (0.752 sec)
#  (val_loss)test_loss = 303.51
# Step 14600: training_loss = 365.13 (0.748 sec)
#  (val_loss)test_loss = 304.85
# Step 14700: training_loss = 268.44 (0.747 sec)
#  (val_loss)test_loss = 315.32
# Step 14800: training_loss = 382.74 (0.749 sec)
#  (val_loss)test_loss = 309.01
# Step 14900: training_loss = 205.93 (0.755 sec)
#  (val_loss)test_loss = 315.85
# Step 15000: training_loss = 158.47 (0.749 sec)
#  (val_loss)test_loss = 304.14
# Step 15100: training_loss = 313.53 (0.751 sec)
#  (val_loss)test_loss = 312.13
# Step 15200: training_loss = 239.49 (0.759 sec)
#  (val_loss)test_loss = 318.69
# Step 15300: training_loss = 226.31 (0.747 sec)
#  (val_loss)test_loss = 311.25
# Step 15400: training_loss = 232.87 (0.771 sec)
#  (val_loss)test_loss = 305.95
# Step 15500: training_loss = 372.53 (0.749 sec)
#  (val_loss)test_loss = 303.90
# Step 15600: training_loss = 532.85 (0.782 sec)
#  (val_loss)test_loss = 305.68
# Step 15700: training_loss = 301.65 (0.751 sec)
#  (val_loss)test_loss = 315.55
# Step 15800: training_loss = 356.34 (0.791 sec)
#  (val_loss)test_loss = 314.54
# Step 15900: training_loss = 192.84 (0.755 sec)
#  (val_loss)test_loss = 314.15
# Step 16000: training_loss = 85.54 (0.749 sec)
#  (val_loss)test_loss = 311.82
# Step 16100: training_loss = 281.68 (0.751 sec)
#  (val_loss)test_loss = 304.89
# Step 16200: training_loss = 139.91 (0.748 sec)
#  (val_loss)test_loss = 312.67
# Step 16300: training_loss = 416.74 (0.750 sec)
#  (val_loss)test_loss = 312.14
# Step 16400: training_loss = 295.03 (0.751 sec)
#  (val_loss)test_loss = 333.16
# Step 16500: training_loss = 272.87 (0.762 sec)
#  (val_loss)test_loss = 315.33
# Step 16600: training_loss = 229.94 (0.763 sec)
#  (val_loss)test_loss = 311.06
# Step 16700: training_loss = 128.63 (0.801 sec)
#  (val_loss)test_loss = 307.90
# Step 16800: training_loss = 362.36 (0.758 sec)
#  (val_loss)test_loss = 310.47
# Step 16900: training_loss = 285.30 (0.748 sec)
#  (val_loss)test_loss = 304.31
# Step 17000: training_loss = 201.29 (0.776 sec)
#  (val_loss)test_loss = 302.82
# Step 17100: training_loss = 150.34 (0.780 sec)
#  (val_loss)test_loss = 309.55
# Step 17200: training_loss = 278.48 (0.753 sec)
#  (val_loss)test_loss = 308.83
# Step 17300: training_loss = 369.24 (0.742 sec)
#  (val_loss)test_loss = 308.60
# Step 17400: training_loss = 197.58 (0.746 sec)
#  (val_loss)test_loss = 305.74
# Step 17500: training_loss = 397.45 (0.749 sec)
#  (val_loss)test_loss = 311.34
# Step 17600: training_loss = 334.16 (0.753 sec)
#  (val_loss)test_loss = 305.62
# Step 17700: training_loss = 392.79 (0.747 sec)
#  (val_loss)test_loss = 304.37
# Step 17800: training_loss = 291.27 (0.747 sec)
#  (val_loss)test_loss = 306.78
# Step 17900: training_loss = 294.93 (0.757 sec)
#  (val_loss)test_loss = 305.48
# Step 18000: training_loss = 235.98 (0.765 sec)
#  (val_loss)test_loss = 310.22
# Step 18100: training_loss = 232.28 (0.769 sec)
#  (val_loss)test_loss = 312.43
# Step 18200: training_loss = 325.05 (0.810 sec)
#  (val_loss)test_loss = 309.36
# Step 18300: training_loss = 351.54 (0.769 sec)
#  (val_loss)test_loss = 305.27
# Step 18400: training_loss = 286.97 (0.773 sec)
#  (val_loss)test_loss = 307.06
# Step 18500: training_loss = 192.52 (0.743 sec)
#  (val_loss)test_loss = 321.75
# Step 18600: training_loss = 204.40 (0.758 sec)
#  (val_loss)test_loss = 308.84
# Step 18700: training_loss = 349.92 (0.760 sec)
#  (val_loss)test_loss = 321.66
# Step 18800: training_loss = 248.39 (0.752 sec)
#  (val_loss)test_loss = 305.94
# Step 18900: training_loss = 271.55 (0.746 sec)
#  (val_loss)test_loss = 300.26
# best shot model: test_loss = 300.26, step = 18900
# model saved successfully.
# Step 19000: training_loss = 308.32 (0.783 sec)
#  (val_loss)test_loss = 307.31
# Step 19100: training_loss = 264.14 (0.784 sec)
#  (val_loss)test_loss = 304.02
# Step 19200: training_loss = 361.66 (0.751 sec)
#  (val_loss)test_loss = 306.97
# Step 19300: training_loss = 342.87 (0.745 sec)
#  (val_loss)test_loss = 303.05
# Step 19400: training_loss = 398.68 (0.750 sec)
#  (val_loss)test_loss = 306.79
# Step 19500: training_loss = 267.54 (0.748 sec)
#  (val_loss)test_loss = 308.03
# Step 19600: training_loss = 375.24 (0.765 sec)
#  (val_loss)test_loss = 302.57
# Step 19700: training_loss = 302.98 (0.752 sec)
#  (val_loss)test_loss = 301.42
# Step 19800: training_loss = 362.00 (0.763 sec)
#  (val_loss)test_loss = 319.40
# Step 19900: training_loss = 391.53 (0.755 sec)
#  (val_loss)test_loss = 305.30
# Step 20000: training_loss = 278.89 (0.788 sec)
#  (val_loss)test_loss = 315.23
# Step 20100: training_loss = 374.53 (0.747 sec)
#  (val_loss)test_loss = 311.18
# Step 20200: training_loss = 218.32 (0.762 sec)
#  (val_loss)test_loss = 310.52
# Step 20300: training_loss = 159.72 (0.758 sec)
#  (val_loss)test_loss = 304.51
# Step 20400: training_loss = 317.46 (0.746 sec)
#  (val_loss)test_loss = 304.07
# Step 20500: training_loss = 234.05 (0.747 sec)
#  (val_loss)test_loss = 304.68
# Step 20600: training_loss = 231.21 (0.747 sec)
#  (val_loss)test_loss = 314.07
# Step 20700: training_loss = 235.48 (0.773 sec)
#  (val_loss)test_loss = 303.12
# Step 20800: training_loss = 360.61 (0.767 sec)
#  (val_loss)test_loss = 303.40
# Step 20900: training_loss = 528.61 (0.749 sec)
#  (val_loss)test_loss = 306.49
# Step 21000: training_loss = 299.66 (0.752 sec)
#  (val_loss)test_loss = 306.45
# Step 21100: training_loss = 357.44 (0.746 sec)
#  (val_loss)test_loss = 312.30
# Step 21200: training_loss = 175.68 (0.753 sec)
#  (val_loss)test_loss = 310.80
# Step 21300: training_loss = 87.18 (0.755 sec)
#  (val_loss)test_loss = 305.78
# Step 21400: training_loss = 282.51 (0.760 sec)
#  (val_loss)test_loss = 301.52
# Step 21500: training_loss = 126.11 (0.753 sec)
#  (val_loss)test_loss = 309.27
# Step 21600: training_loss = 413.47 (0.744 sec)
#  (val_loss)test_loss = 313.61
# Step 21700: training_loss = 292.50 (0.755 sec)
#  (val_loss)test_loss = 310.43
# Step 21800: training_loss = 270.66 (0.759 sec)
#  (val_loss)test_loss = 304.51
# Step 21900: training_loss = 235.26 (0.755 sec)
#  (val_loss)test_loss = 318.89
# Step 22000: training_loss = 126.40 (0.751 sec)
#  (val_loss)test_loss = 306.51
# Step 22100: training_loss = 339.56 (0.751 sec)
#  (val_loss)test_loss = 308.52
# Step 22200: training_loss = 285.07 (0.759 sec)
#  (val_loss)test_loss = 303.89
# Step 22300: training_loss = 180.12 (0.751 sec)
#  (val_loss)test_loss = 310.88
# Step 22400: training_loss = 141.85 (0.752 sec)
#  (val_loss)test_loss = 308.65
# Step 22500: training_loss = 276.26 (0.749 sec)
#  (val_loss)test_loss = 312.90
# Step 22600: training_loss = 369.78 (0.763 sec)
#  (val_loss)test_loss = 310.09
# Step 22700: training_loss = 180.38 (0.767 sec)
#  (val_loss)test_loss = 318.04
# Step 22800: training_loss = 391.42 (0.757 sec)
#  (val_loss)test_loss = 321.66
# Step 22900: training_loss = 351.26 (0.758 sec)
#  (val_loss)test_loss = 311.97
# Step 23000: training_loss = 391.08 (0.802 sec)
#  (val_loss)test_loss = 330.32
# Step 23100: training_loss = 298.43 (0.758 sec)
#  (val_loss)test_loss = 306.18
# Step 23200: training_loss = 290.12 (0.759 sec)
#  (val_loss)test_loss = 315.97
# Step 23300: training_loss = 240.50 (0.760 sec)
#  (val_loss)test_loss = 322.04
# Step 23400: training_loss = 226.27 (0.756 sec)
#  (val_loss)test_loss = 304.80
# Step 23500: training_loss = 322.10 (0.764 sec)
#  (val_loss)test_loss = 307.13
# Step 23600: training_loss = 360.41 (0.766 sec)
#  (val_loss)test_loss = 307.64
# Step 23700: training_loss = 283.26 (0.762 sec)
#  (val_loss)test_loss = 306.47
# Step 23800: training_loss = 193.08 (0.768 sec)
#  (val_loss)test_loss = 315.50
# Step 23900: training_loss = 203.70 (0.786 sec)
#  (val_loss)test_loss = 308.16
# Step 24000: training_loss = 349.68 (0.774 sec)
#  (val_loss)test_loss = 308.00
# Step 24100: training_loss = 257.11 (0.749 sec)
#  (val_loss)test_loss = 310.69
# Step 24200: training_loss = 320.68 (0.757 sec)
#  (val_loss)test_loss = 304.00
# Step 24300: training_loss = 314.52 (0.769 sec)
#  (val_loss)test_loss = 310.98
# Step 24400: training_loss = 254.36 (0.754 sec)
#  (val_loss)test_loss = 315.29
# Step 24500: training_loss = 363.32 (0.747 sec)
#  (val_loss)test_loss = 306.58
# Step 24600: training_loss = 332.95 (0.756 sec)
#  (val_loss)test_loss = 309.21
# Step 24700: training_loss = 403.12 (0.747 sec)
#  (val_loss)test_loss = 316.93
# Step 24800: training_loss = 263.13 (0.761 sec)
#  (val_loss)test_loss = 305.30
# Step 24900: training_loss = 393.29 (0.749 sec)
#  (val_loss)test_loss = 309.21
# Step 25000: training_loss = 300.42 (0.749 sec)
#  (val_loss)test_loss = 302.95
# Step 25100: training_loss = 338.09 (0.751 sec)
#  (val_loss)test_loss = 307.57
# Step 25200: training_loss = 358.61 (0.751 sec)
#  (val_loss)test_loss = 304.81
# Step 25300: training_loss = 259.32 (0.746 sec)
#  (val_loss)test_loss = 313.28
# Step 25400: training_loss = 373.83 (0.740 sec)
#  (val_loss)test_loss = 316.22
# Step 25500: training_loss = 211.25 (0.761 sec)
#  (val_loss)test_loss = 304.55
# Step 25600: training_loss = 164.79 (0.771 sec)
#  (val_loss)test_loss = 309.87
# Step 25700: training_loss = 314.53 (0.753 sec)
#  (val_loss)test_loss = 303.53
# Step 25800: training_loss = 235.05 (0.749 sec)
#  (val_loss)test_loss = 306.58
# Step 25900: training_loss = 224.15 (0.750 sec)
#  (val_loss)test_loss = 305.04
# Step 26000: training_loss = 302.65 (0.753 sec)
#  (val_loss)test_loss = 314.37
# Step 26100: training_loss = 359.68 (0.750 sec)
#  (val_loss)test_loss = 304.50
# Step 26200: training_loss = 535.17 (0.748 sec)
#  (val_loss)test_loss = 315.46
# Step 26300: training_loss = 313.72 (0.752 sec)
#  (val_loss)test_loss = 313.42
# Step 26400: training_loss = 354.00 (0.761 sec)
#  (val_loss)test_loss = 304.23
# Done training for 500 epochs, 26500 steps.
# l1_conv3d/Relu   [None, 130, 130, 110, 16]
# l1_conv3d/max_pool3d   [None, 65, 65, 55, 16]
# l2_conv3d/Relu   [None, 65, 65, 55, 32]
# l2_conv3d/max_pool3d   [None, 33, 33, 28, 32]
# l3_conv3d/Relu   [None, 33, 33, 28, 64]
# l3_conv3d/max_pool3d   [None, 17, 17, 14, 64]
# l4_conv3d/Relu   [None, 17, 17, 14, 64]
# l4_conv3d/max_pool3d   [None, 9, 9, 7, 64]
# l5_conv3d/Relu   [None, 9, 9, 7, 64]
# l5_conv3d/max_pool3d   [None, 5, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-07 16:50:25.935611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-07 16:50:25.935639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-07 16:50:25.935644: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-07 16:50:25.935648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-07 16:50:25.935735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10003 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model loaded successfully.
# test_loss = 300.26, test_accuracy = 0.00.
# Figure(1500x500)
# Figure(640x480)
# MaxPool3D   [None, 65, 65, 55, 8]
# MaxPool3D_1   [None, 33, 33, 28, 16]
# MaxPool3D_2   [None, 17, 17, 14, 32]
# MaxPool3D_3   [None, 9, 9, 7, 64]
# MaxPool3D_4   [None, 5, 5, 4, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# 2019-03-07 16:50:31.828785: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-07 16:50:31.905381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-07 16:50:31.905740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.33GiB
# 2019-03-07 16:50:31.905753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-07 16:50:32.073121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-07 16:50:32.073160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-07 16:50:32.073166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-07 16:50:32.073358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9982 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: training_loss = 107631.84 (2.192 sec)
#  (val_loss)test_loss = 57690.11
# Step 100: training_loss = 1500.36 (0.474 sec)
#  (val_loss)test_loss = 10751.00
# Step 200: training_loss = 72936.23 (0.467 sec)
#  (val_loss)test_loss = 58665.66
# Step 300: training_loss = 688.52 (0.461 sec)
#  (val_loss)test_loss = 6377.51
# Step 400: training_loss = 19985.84 (0.464 sec)
#  (val_loss)test_loss = 2933.45
# Step 500: training_loss = 868.95 (0.483 sec)
#  (val_loss)test_loss = 3952.06
# Step 600: training_loss = 2528.87 (0.472 sec)
#  (val_loss)test_loss = 6319.40
# Step 700: training_loss = 4916.28 (0.463 sec)
#  (val_loss)test_loss = 2318.49
# Step 800: training_loss = 9364.66 (0.466 sec)
#  (val_loss)test_loss = 2165.82
# Step 900: training_loss = 5445.66 (0.462 sec)
#  (val_loss)test_loss = 3594.34
# Step 1000: training_loss = 1264.13 (0.462 sec)
#  (val_loss)test_loss = 5143.81
# Step 1100: training_loss = 1290.06 (0.473 sec)
#  (val_loss)test_loss = 3363.93
# Step 1200: training_loss = 970.19 (0.473 sec)
#  (val_loss)test_loss = 2506.73
# Step 1300: training_loss = 1735.41 (0.467 sec)
#  (val_loss)test_loss = 2869.32
# Step 1400: training_loss = 1051.51 (0.469 sec)
#  (val_loss)test_loss = 2752.19
# Step 1500: training_loss = 1083.16 (0.473 sec)
#  (val_loss)test_loss = 2784.84
# Step 1600: training_loss = 797.96 (0.474 sec)
#  (val_loss)test_loss = 2113.07
# Step 1700: training_loss = 1408.11 (0.465 sec)
#  (val_loss)test_loss = 2512.93
# Step 1800: training_loss = 1401.11 (0.459 sec)
#  (val_loss)test_loss = 2464.09
# Step 1900: training_loss = 1679.91 (0.463 sec)
#  (val_loss)test_loss = 2261.22
# Step 2000: training_loss = 4195.42 (0.463 sec)
#  (val_loss)test_loss = 2409.94
# Step 2100: training_loss = 984.76 (0.466 sec)
#  (val_loss)test_loss = 1857.92
# Step 2200: training_loss = 1231.98 (0.464 sec)
#  (val_loss)test_loss = 1742.62
# Step 2300: training_loss = 1892.01 (0.464 sec)
#  (val_loss)test_loss = 1835.13
# Step 2400: training_loss = 801.05 (0.466 sec)
#  (val_loss)test_loss = 2097.00
# Step 2500: training_loss = 973.53 (0.474 sec)
#  (val_loss)test_loss = 1651.17
# Step 2600: training_loss = 1620.57 (0.466 sec)
#  (val_loss)test_loss = 1610.56
# Step 2700: training_loss = 1285.21 (0.465 sec)
#  (val_loss)test_loss = 1885.93
# Step 2800: training_loss = 1596.25 (0.467 sec)
#  (val_loss)test_loss = 1843.08
# Step 2900: training_loss = 1535.72 (0.465 sec)
#  (val_loss)test_loss = 1507.17
# Step 3000: training_loss = 1307.36 (0.462 sec)
#  (val_loss)test_loss = 1720.57
# Step 3100: training_loss = 719.19 (0.472 sec)
#  (val_loss)test_loss = 1354.58
# Step 3200: training_loss = 1313.91 (0.475 sec)
#  (val_loss)test_loss = 1359.31
# Step 3300: training_loss = 2346.30 (0.465 sec)
#  (val_loss)test_loss = 1700.47
# Step 3400: training_loss = 1640.67 (0.472 sec)
#  (val_loss)test_loss = 1886.83
# Step 3500: training_loss = 1561.49 (0.462 sec)
#  (val_loss)test_loss = 1249.48
# Step 3600: training_loss = 1464.27 (0.466 sec)
#  (val_loss)test_loss = 1509.75
# Step 3700: training_loss = 1680.28 (0.466 sec)
#  (val_loss)test_loss = 1557.59
# Step 3800: training_loss = 1033.85 (0.461 sec)
#  (val_loss)test_loss = 1231.12
# Step 3900: training_loss = 1572.31 (0.467 sec)
#  (val_loss)test_loss = 1285.24
# Step 4000: training_loss = 2083.54 (0.462 sec)
#  (val_loss)test_loss = 1181.08
# Step 4100: training_loss = 860.53 (0.466 sec)
#  (val_loss)test_loss = 1082.84
# Step 4200: training_loss = 1137.89 (0.475 sec)
#  (val_loss)test_loss = 1114.22
# Step 4300: training_loss = 1413.42 (0.464 sec)
#  (val_loss)test_loss = 1387.48
# Step 4400: training_loss = 1155.97 (0.468 sec)
#  (val_loss)test_loss = 1155.41
# Step 4500: training_loss = 1089.85 (0.463 sec)
#  (val_loss)test_loss = 1151.11
# Step 4600: training_loss = 1256.21 (0.474 sec)
#  (val_loss)test_loss = 1041.55
# Step 4700: training_loss = 1479.98 (0.471 sec)
#  (val_loss)test_loss = 1275.42
# Step 4800: training_loss = 1088.49 (0.465 sec)
#  (val_loss)test_loss = 1456.57
# Step 4900: training_loss = 1307.08 (0.462 sec)
#  (val_loss)test_loss = 1152.94
# Step 5000: training_loss = 2848.17 (0.472 sec)
#  (val_loss)test_loss = 1310.65
# Step 5100: training_loss = 766.28 (0.465 sec)
#  (val_loss)test_loss = 1196.01
# Step 5200: training_loss = 1259.80 (0.464 sec)
#  (val_loss)test_loss = 1340.67
# Step 5300: training_loss = 1466.36 (0.460 sec)
#  (val_loss)test_loss = 1354.50
# Step 5400: training_loss = 848.23 (0.468 sec)
#  (val_loss)test_loss = 982.71
# best shot model: test_loss = 982.71, step = 5400
# model saved successfully.
# Step 5500: training_loss = 1612.63 (0.461 sec)
#  (val_loss)test_loss = 1426.67
# Step 5600: training_loss = 1355.10 (0.473 sec)
#  (val_loss)test_loss = 1203.42
# Step 5700: training_loss = 1960.31 (0.462 sec)
#  (val_loss)test_loss = 1321.76
# Step 5800: training_loss = 1117.52 (0.465 sec)
#  (val_loss)test_loss = 1162.06
# Step 5900: training_loss = 1463.44 (0.463 sec)
#  (val_loss)test_loss = 1289.34
# Step 6000: training_loss = 1426.37 (0.462 sec)
#  (val_loss)test_loss = 1224.05
# Step 6100: training_loss = 1141.18 (0.465 sec)
#  (val_loss)test_loss = 1232.69
# Step 6200: training_loss = 2083.17 (0.462 sec)
#  (val_loss)test_loss = 1303.65
# Step 6300: training_loss = 1267.19 (0.463 sec)
#  (val_loss)test_loss = 1160.69
# Step 6400: training_loss = 1635.39 (0.464 sec)
#  (val_loss)test_loss = 1215.14
# Step 6500: training_loss = 733.99 (0.466 sec)
#  (val_loss)test_loss = 1359.57
# Step 6600: training_loss = 1112.32 (0.465 sec)
#  (val_loss)test_loss = 1135.38
# Step 6700: training_loss = 1257.25 (0.469 sec)
#  (val_loss)test_loss = 1165.10
# Step 6800: training_loss = 720.27 (0.475 sec)
#  (val_loss)test_loss = 1223.56
# Step 6900: training_loss = 1101.29 (0.460 sec)
#  (val_loss)test_loss = 1225.12
# Step 7000: training_loss = 1436.77 (0.474 sec)
#  (val_loss)test_loss = 1127.28
# Step 7100: training_loss = 1397.05 (0.475 sec)
#  (val_loss)test_loss = 1175.02
# Step 7200: training_loss = 1249.29 (0.466 sec)
#  (val_loss)test_loss = 1274.36
# Step 7300: training_loss = 1531.95 (0.475 sec)
#  (val_loss)test_loss = 1138.93
# Step 7400: training_loss = 1164.79 (0.466 sec)
#  (val_loss)test_loss = 1117.62
# Step 7500: training_loss = 1728.49 (0.465 sec)
#  (val_loss)test_loss = 1255.55
# Step 7600: training_loss = 1180.57 (0.473 sec)
#  (val_loss)test_loss = 1153.23
# Step 7700: training_loss = 1050.19 (0.464 sec)
#  (val_loss)test_loss = 1129.30
# Step 7800: training_loss = 1169.77 (0.464 sec)
#  (val_loss)test_loss = 1107.94
# Step 7900: training_loss = 1062.55 (0.475 sec)
#  (val_loss)test_loss = 1077.67
# Step 8000: training_loss = 1135.98 (0.468 sec)
#  (val_loss)test_loss = 1068.49
# Step 8100: training_loss = 1297.50 (0.465 sec)
#  (val_loss)test_loss = 1153.50
# Step 8200: training_loss = 1584.50 (0.475 sec)
#  (val_loss)test_loss = 1124.58
# Step 8300: training_loss = 907.43 (0.475 sec)
#  (val_loss)test_loss = 1120.63
# Step 8400: training_loss = 536.24 (0.465 sec)
#  (val_loss)test_loss = 1139.87
# Step 8500: training_loss = 1217.72 (0.464 sec)
#  (val_loss)test_loss = 1142.02
# Step 8600: training_loss = 1273.51 (0.463 sec)
#  (val_loss)test_loss = 1092.01
# Step 8700: training_loss = 1527.33 (0.464 sec)
#  (val_loss)test_loss = 1038.59
# Step 8800: training_loss = 1343.00 (0.466 sec)
#  (val_loss)test_loss = 1106.34
# Step 8900: training_loss = 1112.29 (0.467 sec)
#  (val_loss)test_loss = 1017.38
# Step 9000: training_loss = 1519.20 (0.464 sec)
#  (val_loss)test_loss = 1054.92
# Step 9100: training_loss = 1339.38 (0.466 sec)
#  (val_loss)test_loss = 1122.27
# Step 9200: training_loss = 1127.87 (0.470 sec)
#  (val_loss)test_loss = 1100.49
# Step 9300: training_loss = 1884.18 (0.463 sec)
#  (val_loss)test_loss = 1129.75
# Step 9400: training_loss = 1327.92 (0.463 sec)
#  (val_loss)test_loss = 1168.33
# Step 9500: training_loss = 1103.72 (0.460 sec)
#  (val_loss)test_loss = 1097.74
# Step 9600: training_loss = 1450.91 (0.472 sec)
#  (val_loss)test_loss = 1206.93
# Step 9700: training_loss = 901.81 (0.462 sec)
#  (val_loss)test_loss = 1070.68
# Step 9800: training_loss = 1000.90 (0.475 sec)
#  (val_loss)test_loss = 1048.02
# Step 9900: training_loss = 1115.66 (0.476 sec)
#  (val_loss)test_loss = 991.44
# Step 10000: training_loss = 1282.58 (0.482 sec)
#  (val_loss)test_loss = 1056.72
# Step 10100: training_loss = 882.36 (0.464 sec)
#  (val_loss)test_loss = 1061.54
# Step 10200: training_loss = 1355.28 (0.465 sec)
#  (val_loss)test_loss = 1103.55
# Step 10300: training_loss = 1831.03 (0.472 sec)
#  (val_loss)test_loss = 1081.34
# Step 10400: training_loss = 807.63 (0.464 sec)
#  (val_loss)test_loss = 1036.49
# Step 10500: training_loss = 1290.07 (0.463 sec)
#  (val_loss)test_loss = 1084.52
# Step 10600: training_loss = 1514.88 (0.480 sec)
#  (val_loss)test_loss = 1044.77
# Step 10700: training_loss = 920.02 (0.464 sec)
#  (val_loss)test_loss = 992.02
# Step 10800: training_loss = 1458.75 (0.483 sec)
#  (val_loss)test_loss = 1040.76
# Step 10900: training_loss = 1303.98 (0.470 sec)
#  (val_loss)test_loss = 1087.44
# Step 11000: training_loss = 1720.15 (0.474 sec)
#  (val_loss)test_loss = 1068.05
# Step 11100: training_loss = 1198.96 (0.475 sec)
#  (val_loss)test_loss = 1127.51
# Step 11200: training_loss = 1415.17 (0.468 sec)
#  (val_loss)test_loss = 1085.52
# Step 11300: training_loss = 1513.38 (0.476 sec)
#  (val_loss)test_loss = 1115.01
# Step 11400: training_loss = 971.84 (0.459 sec)
#  (val_loss)test_loss = 1060.91
# Step 11500: training_loss = 1787.56 (0.459 sec)
#  (val_loss)test_loss = 1076.02
# Step 11600: training_loss = 1093.01 (0.460 sec)
#  (val_loss)test_loss = 924.34
# best shot model: test_loss = 924.34, step = 11600
# model saved successfully.
# Step 11700: training_loss = 1557.34 (0.468 sec)
#  (val_loss)test_loss = 1059.70
# Step 11800: training_loss = 637.14 (0.466 sec)
#  (val_loss)test_loss = 1056.14
# Step 11900: training_loss = 1095.05 (0.459 sec)
#  (val_loss)test_loss = 1048.79
# Step 12000: training_loss = 1126.88 (0.474 sec)
#  (val_loss)test_loss = 1025.90
# Step 12100: training_loss = 733.72 (0.467 sec)
#  (val_loss)test_loss = 1104.01
# Step 12200: training_loss = 989.31 (0.464 sec)
#  (val_loss)test_loss = 1021.59
# Step 12300: training_loss = 1395.35 (0.459 sec)
#  (val_loss)test_loss = 1056.39
# Step 12400: training_loss = 1331.25 (0.474 sec)
#  (val_loss)test_loss = 1040.55
# Step 12500: training_loss = 989.56 (0.460 sec)
#  (val_loss)test_loss = 918.14
# best shot model: test_loss = 918.14, step = 12500
# model saved successfully.
# Step 12600: training_loss = 1549.45 (0.463 sec)
#  (val_loss)test_loss = 1060.72
# Step 12700: training_loss = 1101.74 (0.462 sec)
#  (val_loss)test_loss = 1039.59
# Step 12800: training_loss = 1272.69 (0.466 sec)
#  (val_loss)test_loss = 1025.71
# Step 12900: training_loss = 1194.15 (0.463 sec)
#  (val_loss)test_loss = 1109.84
# Step 13000: training_loss = 983.84 (0.495 sec)
#  (val_loss)test_loss = 1075.18
# Step 13100: training_loss = 961.13 (0.469 sec)
#  (val_loss)test_loss = 1001.45
# Step 13200: training_loss = 1108.14 (0.468 sec)
#  (val_loss)test_loss = 1111.63
# Step 13300: training_loss = 1071.52 (0.461 sec)
#  (val_loss)test_loss = 1013.49
# Step 13400: training_loss = 1155.04 (0.466 sec)
#  (val_loss)test_loss = 961.03
# Step 13500: training_loss = 1451.83 (0.471 sec)
#  (val_loss)test_loss = 1031.06
# Step 13600: training_loss = 851.83 (0.477 sec)
#  (val_loss)test_loss = 1015.88
# Step 13700: training_loss = 520.51 (0.466 sec)
#  (val_loss)test_loss = 1054.51
# Step 13800: training_loss = 1127.14 (0.458 sec)
#  (val_loss)test_loss = 1094.78
# Step 13900: training_loss = 1179.37 (0.463 sec)
#  (val_loss)test_loss = 1087.32
# Step 14000: training_loss = 1494.32 (0.469 sec)
#  (val_loss)test_loss = 1049.03
# Step 14100: training_loss = 1274.27 (0.460 sec)
#  (val_loss)test_loss = 1095.67
# Step 14200: training_loss = 1062.01 (0.463 sec)
#  (val_loss)test_loss = 986.19
# Step 14300: training_loss = 1291.46 (0.465 sec)
#  (val_loss)test_loss = 904.88
# best shot model: test_loss = 904.88, step = 14300
# model saved successfully.
# Step 14400: training_loss = 1201.95 (0.466 sec)
#  (val_loss)test_loss = 1026.79
# Step 14500: training_loss = 917.34 (0.471 sec)
#  (val_loss)test_loss = 972.63
# Step 14600: training_loss = 1625.65 (0.466 sec)
#  (val_loss)test_loss = 997.73
# Step 14700: training_loss = 1108.72 (0.467 sec)
#  (val_loss)test_loss = 1036.60
# Step 14800: training_loss = 984.02 (0.463 sec)
#  (val_loss)test_loss = 1008.16
# Step 14900: training_loss = 1238.81 (0.463 sec)
#  (val_loss)test_loss = 1028.57
# Step 15000: training_loss = 816.85 (0.468 sec)
#  (val_loss)test_loss = 994.34
# Step 15100: training_loss = 855.73 (0.460 sec)
#  (val_loss)test_loss = 932.01
# Step 15200: training_loss = 1110.10 (0.476 sec)
#  (val_loss)test_loss = 948.24
# Step 15300: training_loss = 1235.32 (0.463 sec)
#  (val_loss)test_loss = 1056.90
# Step 15400: training_loss = 756.03 (0.464 sec)
#  (val_loss)test_loss = 949.88
# Step 15500: training_loss = 1288.10 (0.474 sec)
#  (val_loss)test_loss = 1043.74
# Step 15600: training_loss = 1738.78 (0.464 sec)
#  (val_loss)test_loss = 1073.78
# Step 15700: training_loss = 642.84 (0.463 sec)
#  (val_loss)test_loss = 982.94
# Step 15800: training_loss = 1126.31 (0.477 sec)
#  (val_loss)test_loss = 1003.06
# Step 15900: training_loss = 1272.54 (0.477 sec)
#  (val_loss)test_loss = 1012.36
# Step 16000: training_loss = 708.79 (0.499 sec)
#  (val_loss)test_loss = 865.07
# best shot model: test_loss = 865.07, step = 16000
# model saved successfully.
# Step 16100: training_loss = 1257.36 (0.478 sec)
#  (val_loss)test_loss = 937.03
# Step 16200: training_loss = 1137.78 (0.479 sec)
#  (val_loss)test_loss = 982.11
# Step 16300: training_loss = 1489.86 (0.485 sec)
#  (val_loss)test_loss = 959.55
# Step 16400: training_loss = 1011.26 (0.492 sec)
#  (val_loss)test_loss = 1019.23
# Step 16500: training_loss = 1296.10 (0.471 sec)
#  (val_loss)test_loss = 1045.28
# Step 16600: training_loss = 1230.30 (0.500 sec)
#  (val_loss)test_loss = 944.88
# Step 16700: training_loss = 917.74 (0.470 sec)
#  (val_loss)test_loss = 1020.48
# Step 16800: training_loss = 1611.29 (0.472 sec)
#  (val_loss)test_loss = 999.94
# Step 16900: training_loss = 1040.32 (0.476 sec)
#  (val_loss)test_loss = 880.45
# Step 17000: training_loss = 1312.14 (0.466 sec)
#  (val_loss)test_loss = 907.34
# Step 17100: training_loss = 567.01 (0.488 sec)
#  (val_loss)test_loss = 993.23
# Step 17200: training_loss = 969.97 (0.473 sec)
#  (val_loss)test_loss = 968.06
# Step 17300: training_loss = 1083.77 (0.466 sec)
#  (val_loss)test_loss = 998.70
# Step 17400: training_loss = 637.00 (0.463 sec)
#  (val_loss)test_loss = 1009.45
# Step 17500: training_loss = 908.07 (0.468 sec)
#  (val_loss)test_loss = 946.06
# Step 17600: training_loss = 1304.70 (0.465 sec)
#  (val_loss)test_loss = 998.29
# Step 17700: training_loss = 1212.00 (0.461 sec)
#  (val_loss)test_loss = 945.93
# Step 17800: training_loss = 897.02 (0.476 sec)
#  (val_loss)test_loss = 848.95
# best shot model: test_loss = 848.95, step = 17800
# model saved successfully.
# Step 17900: training_loss = 1369.28 (0.478 sec)
#  (val_loss)test_loss = 972.68
# Step 18000: training_loss = 997.25 (0.466 sec)
#  (val_loss)test_loss = 929.94
# Step 18100: training_loss = 1086.76 (0.469 sec)
#  (val_loss)test_loss = 911.86
# Step 18200: training_loss = 1102.25 (0.466 sec)
#  (val_loss)test_loss = 1012.74
# Step 18300: training_loss = 881.24 (0.464 sec)
#  (val_loss)test_loss = 989.33
# Step 18400: training_loss = 864.94 (0.463 sec)
#  (val_loss)test_loss = 929.37
# Step 18500: training_loss = 925.54 (0.466 sec)
#  (val_loss)test_loss = 980.95
# Step 18600: training_loss = 1011.83 (0.477 sec)
#  (val_loss)test_loss = 930.86
# Step 18700: training_loss = 1009.83 (0.460 sec)
#  (val_loss)test_loss = 833.79
# best shot model: test_loss = 833.79, step = 18700
# model saved successfully.
# Step 18800: training_loss = 1248.54 (0.460 sec)
#  (val_loss)test_loss = 940.27
# Step 18900: training_loss = 812.85 (0.464 sec)
#  (val_loss)test_loss = 937.13
# Step 19000: training_loss = 431.50 (0.465 sec)
#  (val_loss)test_loss = 919.88
# Step 19100: training_loss = 940.14 (0.466 sec)
#  (val_loss)test_loss = 961.03
# Step 19200: training_loss = 1070.07 (0.475 sec)
#  (val_loss)test_loss = 943.55
# Step 19300: training_loss = 1327.83 (0.466 sec)
#  (val_loss)test_loss = 933.90
# Step 19400: training_loss = 1122.96 (0.466 sec)
#  (val_loss)test_loss = 952.58
# Step 19500: training_loss = 993.13 (0.473 sec)
#  (val_loss)test_loss = 900.13
# Step 19600: training_loss = 1175.36 (0.466 sec)
#  (val_loss)test_loss = 812.07
# best shot model: test_loss = 812.07, step = 19600
# model saved successfully.
# Step 19700: training_loss = 1025.80 (0.468 sec)
#  (val_loss)test_loss = 907.47
# Step 19800: training_loss = 830.86 (0.474 sec)
#  (val_loss)test_loss = 852.37
# Step 19900: training_loss = 1411.23 (0.462 sec)
#  (val_loss)test_loss = 922.54
# Step 20000: training_loss = 1017.91 (0.462 sec)
#  (val_loss)test_loss = 961.03
# Step 20100: training_loss = 877.81 (0.459 sec)
#  (val_loss)test_loss = 883.72
# Step 20200: training_loss = 1092.18 (0.466 sec)
#  (val_loss)test_loss = 928.71
# Step 20300: training_loss = 729.28 (0.473 sec)
#  (val_loss)test_loss = 910.68
# Step 20400: training_loss = 777.87 (0.496 sec)
#  (val_loss)test_loss = 816.06
# Step 20500: training_loss = 918.82 (0.469 sec)
#  (val_loss)test_loss = 781.03
# best shot model: test_loss = 781.03, step = 20500
# model saved successfully.
# Step 20600: training_loss = 1014.93 (0.474 sec)
#  (val_loss)test_loss = 894.86
# Step 20700: training_loss = 691.16 (0.465 sec)
#  (val_loss)test_loss = 839.44
# Step 20800: training_loss = 1078.34 (0.466 sec)
#  (val_loss)test_loss = 907.25
# Step 20900: training_loss = 1511.44 (0.467 sec)
#  (val_loss)test_loss = 939.21
# Step 21000: training_loss = 554.47 (0.466 sec)
#  (val_loss)test_loss = 833.10
# Step 21100: training_loss = 949.35 (0.467 sec)
#  (val_loss)test_loss = 879.71
# Step 21200: training_loss = 1061.96 (0.464 sec)
#  (val_loss)test_loss = 891.52
# Step 21300: training_loss = 656.19 (0.488 sec)
#  (val_loss)test_loss = 762.67
# best shot model: test_loss = 762.67, step = 21300
# model saved successfully.
# Step 21400: training_loss = 1050.98 (0.466 sec)
#  (val_loss)test_loss = 793.94
# Step 21500: training_loss = 937.20 (0.467 sec)
#  (val_loss)test_loss = 862.76
# Step 21600: training_loss = 1307.34 (0.470 sec)
#  (val_loss)test_loss = 849.26
# Step 21700: training_loss = 856.79 (0.470 sec)
#  (val_loss)test_loss = 857.37
# Step 21800: training_loss = 1065.28 (0.467 sec)
#  (val_loss)test_loss = 905.20
# Step 21900: training_loss = 1034.06 (0.484 sec)
#  (val_loss)test_loss = 821.75
# Step 22000: training_loss = 756.10 (0.478 sec)
#  (val_loss)test_loss = 876.80
# Step 22100: training_loss = 1274.35 (0.465 sec)
#  (val_loss)test_loss = 822.31
# Step 22200: training_loss = 875.98 (0.477 sec)
#  (val_loss)test_loss = 729.97
# best shot model: test_loss = 729.97, step = 22200
# model saved successfully.
# Step 22300: training_loss = 1066.78 (0.492 sec)
#  (val_loss)test_loss = 802.48
# Step 22400: training_loss = 473.96 (0.486 sec)
#  (val_loss)test_loss = 828.15
# Step 22500: training_loss = 836.86 (0.470 sec)
#  (val_loss)test_loss = 825.36
# Step 22600: training_loss = 888.75 (0.478 sec)
#  (val_loss)test_loss = 838.82
# Step 22700: training_loss = 543.08 (0.468 sec)
#  (val_loss)test_loss = 826.87
# Step 22800: training_loss = 830.59 (0.474 sec)
#  (val_loss)test_loss = 820.24
# Step 22900: training_loss = 1072.67 (0.480 sec)
#  (val_loss)test_loss = 821.95
# Step 23000: training_loss = 1019.98 (0.478 sec)
#  (val_loss)test_loss = 759.74
# Step 23100: training_loss = 774.79 (0.481 sec)
#  (val_loss)test_loss = 668.93
# best shot model: test_loss = 668.93, step = 23100
# model saved successfully.
# Step 23200: training_loss = 1008.25 (0.466 sec)
#  (val_loss)test_loss = 759.83
# Step 23300: training_loss = 859.92 (0.477 sec)
#  (val_loss)test_loss = 799.48
# Step 23400: training_loss = 916.72 (0.474 sec)
#  (val_loss)test_loss = 809.11
# Step 23500: training_loss = 897.17 (0.466 sec)
#  (val_loss)test_loss = 843.79
# Step 23600: training_loss = 750.87 (0.465 sec)
#  (val_loss)test_loss = 801.81
# Step 23700: training_loss = 729.55 (0.467 sec)
#  (val_loss)test_loss = 791.13
# Step 23800: training_loss = 723.32 (0.467 sec)
#  (val_loss)test_loss = 799.96
# Step 23900: training_loss = 771.55 (0.487 sec)
#  (val_loss)test_loss = 724.31
# Step 24000: training_loss = 891.73 (0.464 sec)
#  (val_loss)test_loss = 667.57
# best shot model: test_loss = 667.57, step = 24000
# model saved successfully.
# Step 24100: training_loss = 976.72 (0.478 sec)
#  (val_loss)test_loss = 790.75
# Step 24200: training_loss = 700.97 (0.471 sec)
#  (val_loss)test_loss = 782.96
# Step 24300: training_loss = 383.71 (0.467 sec)
#  (val_loss)test_loss = 780.29
# Step 24400: training_loss = 766.81 (0.481 sec)
#  (val_loss)test_loss = 796.09
# Step 24500: training_loss = 890.12 (0.463 sec)
#  (val_loss)test_loss = 786.42
# Step 24600: training_loss = 1053.67 (0.486 sec)
#  (val_loss)test_loss = 771.91
# Step 24700: training_loss = 917.67 (0.481 sec)
#  (val_loss)test_loss = 761.72
# Step 24800: training_loss = 795.99 (0.486 sec)
#  (val_loss)test_loss = 688.12
# Step 24900: training_loss = 988.09 (0.468 sec)
#  (val_loss)test_loss = 668.60
# Step 25000: training_loss = 838.25 (0.465 sec)
#  (val_loss)test_loss = 754.07
# Step 25100: training_loss = 715.80 (0.473 sec)
#  (val_loss)test_loss = 734.01
# Step 25200: training_loss = 1083.78 (0.494 sec)
#  (val_loss)test_loss = 764.76
# Step 25300: training_loss = 799.87 (0.484 sec)
#  (val_loss)test_loss = 762.29
# Step 25400: training_loss = 796.60 (0.465 sec)
#  (val_loss)test_loss = 768.28
# Step 25500: training_loss = 797.49 (0.463 sec)
#  (val_loss)test_loss = 744.30
# Step 25600: training_loss = 580.49 (0.474 sec)
#  (val_loss)test_loss = 704.46
# Step 25700: training_loss = 651.07 (0.468 sec)
#  (val_loss)test_loss = 636.73
# best shot model: test_loss = 636.73, step = 25700
# model saved successfully.
# Step 25800: training_loss = 755.67 (0.477 sec)
#  (val_loss)test_loss = 661.86
# Step 25900: training_loss = 773.66 (0.474 sec)
#  (val_loss)test_loss = 729.65
# Step 26000: training_loss = 565.69 (0.486 sec)
#  (val_loss)test_loss = 691.50
# Step 26100: training_loss = 914.60 (0.464 sec)
#  (val_loss)test_loss = 756.15
# Step 26200: training_loss = 1162.20 (0.468 sec)
#  (val_loss)test_loss = 726.76
# Step 26300: training_loss = 511.68 (0.470 sec)
#  (val_loss)test_loss = 729.46
# Step 26400: training_loss = 795.98 (0.472 sec)
#  (val_loss)test_loss = 740.19
# Done training for 500 epochs, 26500 steps.
# Traceback (most recent call last):
#   File "demo_1_2.py", line 369, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/home/woody/vpython/vp3.5.2/lib/python3.5/site-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "demo_1_2.py", line 313, in main
#     run_training()
#   File "demo_1_2.py", line 252, in run_training
#     np.save(plt_data_path_name, np.array([losses,acces]))
# NameError: name 'acces' is not defined

# %% [markdown]
# l1_conv3d/Relu   [None, 130, 130, 110, 16]
# l1_conv3d/max_pool3d   [None, 65, 65, 55, 16]
# l2_conv3d/Relu   [None, 65, 65, 55, 32]
# l2_conv3d/max_pool3d   [None, 33, 33, 28, 32]
# l3_conv3d/Relu   [None, 33, 33, 28, 64]
# l3_conv3d/max_pool3d   [None, 17, 17, 14, 64]
# l4_conv3d/Relu   [None, 17, 17, 14, 64]
# l4_conv3d/max_pool3d   [None, 9, 9, 7, 64]
# l5_conv3d/Relu   [None, 9, 9, 7, 64]
# l5_conv3d/max_pool3d   [None, 5, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-05 21:20:23.338765: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-05 21:20:23.422099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-05 21:20:23.422458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.29GiB
# 2019-03-05 21:20:23.422472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-05 21:20:23.598899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-05 21:20:23.598923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-05 21:20:23.598929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-05 21:20:23.599084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9945 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: training_loss = 2842651.50 (3.248 sec)
#  (val_loss)test_loss = 1206660.00
# Step 100: training_loss = 2136.75 (0.808 sec)
#  (val_loss)test_loss = 2355.77
# Step 200: training_loss = 3021.07 (0.771 sec)
#  (val_loss)test_loss = 2332.73
# Step 300: training_loss = 2711.74 (0.765 sec)
#  (val_loss)test_loss = 2261.16
# Step 400: training_loss = 3187.76 (0.753 sec)
#  (val_loss)test_loss = 2226.69
# Step 500: training_loss = 2148.18 (0.749 sec)
#  (val_loss)test_loss = 2131.54
# Step 600: training_loss = 2428.75 (0.758 sec)
#  (val_loss)test_loss = 2050.34
# Step 700: training_loss = 2519.15 (0.758 sec)
#  (val_loss)test_loss = 1991.47
# Step 800: training_loss = 1820.44 (0.758 sec)
#  (val_loss)test_loss = 1922.60
# Step 900: training_loss = 2895.77 (0.760 sec)
#  (val_loss)test_loss = 1835.42
# Step 1000: training_loss = 1933.29 (0.764 sec)
#  (val_loss)test_loss = 1780.74
# Step 1100: training_loss = 2272.71 (0.780 sec)
#  (val_loss)test_loss = 1710.93
# Step 1200: training_loss = 1004.35 (0.760 sec)
#  (val_loss)test_loss = 1688.17
# Step 1300: training_loss = 1575.36 (0.759 sec)
#  (val_loss)test_loss = 1651.33
# Step 1400: training_loss = 1685.21 (0.759 sec)
#  (val_loss)test_loss = 1530.07
# Step 1500: training_loss = 903.01 (0.752 sec)
#  (val_loss)test_loss = 1449.46
# Step 1600: training_loss = 1336.87 (0.754 sec)
#  (val_loss)test_loss = 1434.45
# Step 1700: training_loss = 1696.58 (0.757 sec)
#  (val_loss)test_loss = 1363.41
# Step 1800: training_loss = 1563.32 (0.754 sec)
#  (val_loss)test_loss = 1339.14
# Step 1900: training_loss = 1267.16 (0.762 sec)
#  (val_loss)test_loss = 1311.07
# Step 2000: training_loss = 1612.27 (0.764 sec)
#  (val_loss)test_loss = 1212.67
# Step 2100: training_loss = 1123.74 (0.756 sec)
#  (val_loss)test_loss = 1115.69
# Step 2200: training_loss = 1421.47 (0.761 sec)
#  (val_loss)test_loss = 1098.95
# Step 2300: training_loss = 999.21 (0.751 sec)
#  (val_loss)test_loss = 1034.09
# Step 2400: training_loss = 809.34 (0.759 sec)
#  (val_loss)test_loss = 963.64
# Step 2500: training_loss = 845.69 (0.765 sec)
#  (val_loss)test_loss = 931.47
# Step 2600: training_loss = 889.21 (0.764 sec)
#  (val_loss)test_loss = 935.86
# Step 2700: training_loss = 855.39 (0.758 sec)
#  (val_loss)test_loss = 887.25
# Step 2800: training_loss = 977.03 (0.768 sec)
#  (val_loss)test_loss = 871.55
# Step 2900: training_loss = 1026.75 (0.748 sec)
#  (val_loss)test_loss = 785.97
# Step 3000: training_loss = 513.43 (0.771 sec)
#  (val_loss)test_loss = 695.72
# Step 3100: training_loss = 258.84 (0.750 sec)
#  (val_loss)test_loss = 716.96
# Step 3200: training_loss = 581.67 (0.760 sec)
#  (val_loss)test_loss = 643.52
# Step 3300: training_loss = 667.14 (0.758 sec)
#  (val_loss)test_loss = 597.73
# Step 3400: training_loss = 901.19 (0.760 sec)
#  (val_loss)test_loss = 603.12
# Step 3500: training_loss = 718.87 (0.759 sec)
#  (val_loss)test_loss = 599.23
# Step 3600: training_loss = 521.17 (0.755 sec)
#  (val_loss)test_loss = 538.84
# Step 3700: training_loss = 676.75 (0.758 sec)
#  (val_loss)test_loss = 520.04
# Step 3800: training_loss = 467.73 (0.764 sec)
#  (val_loss)test_loss = 454.41
# best shot model: test_loss = 454.41, step = 3800
# model saved successfully.
# Step 3900: training_loss = 400.74 (0.762 sec)
#  (val_loss)test_loss = 471.24
# Step 4000: training_loss = 719.11 (0.762 sec)
#  (val_loss)test_loss = 433.66
# best shot model: test_loss = 433.66, step = 4000
# model saved successfully.
# Step 4100: training_loss = 464.01 (0.755 sec)
#  (val_loss)test_loss = 430.95
# best shot model: test_loss = 430.95, step = 4100
# model saved successfully.
# Step 4200: training_loss = 406.96 (0.768 sec)
#  (val_loss)test_loss = 396.13
# best shot model: test_loss = 396.13, step = 4200
# model saved successfully.
# Step 4300: training_loss = 404.16 (0.758 sec)
#  (val_loss)test_loss = 419.16
# Step 4400: training_loss = 271.93 (0.758 sec)
#  (val_loss)test_loss = 408.86
# Step 4500: training_loss = 349.34 (0.755 sec)
#  (val_loss)test_loss = 401.01
# Step 4600: training_loss = 354.61 (0.767 sec)
#  (val_loss)test_loss = 403.39
# Step 4700: training_loss = 316.45 (0.751 sec)
#  (val_loss)test_loss = 371.88
# best shot model: test_loss = 371.88, step = 4700
# model saved successfully.
# Step 4800: training_loss = 250.96 (0.757 sec)
#  (val_loss)test_loss = 367.76
# best shot model: test_loss = 367.76, step = 4800
# model saved successfully.
# Step 4900: training_loss = 485.94 (0.753 sec)
#  (val_loss)test_loss = 373.31
# Step 5000: training_loss = 666.73 (0.756 sec)
#  (val_loss)test_loss = 373.46
# Step 5100: training_loss = 197.77 (0.752 sec)
#  (val_loss)test_loss = 333.66
# best shot model: test_loss = 333.66, step = 5100
# model saved successfully.
# Step 5200: training_loss = 383.57 (0.765 sec)
#  (val_loss)test_loss = 330.13
# best shot model: test_loss = 330.13, step = 5200
# model saved successfully.
# Done training for 100 epochs, 5300 steps.
# l1_conv3d/Relu   [None, 130, 130, 110, 16]
# l1_conv3d/max_pool3d   [None, 65, 65, 55, 16]
# l2_conv3d/Relu   [None, 65, 65, 55, 32]
# l2_conv3d/max_pool3d   [None, 33, 33, 28, 32]
# l3_conv3d/Relu   [None, 33, 33, 28, 64]
# l3_conv3d/max_pool3d   [None, 17, 17, 14, 64]
# l4_conv3d/Relu   [None, 17, 17, 14, 64]
# l4_conv3d/max_pool3d   [None, 9, 9, 7, 64]
# l5_conv3d/Relu   [None, 9, 9, 7, 64]
# l5_conv3d/max_pool3d   [None, 5, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-05 22:28:45.091585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-05 22:28:45.091617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-05 22:28:45.091622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-05 22:28:45.091626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-05 22:28:45.091709: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9945 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model loaded successfully.
# test_loss = 330.13, test_accuracy = 0.00.
# MaxPool3D   [None, 65, 65, 55, 8]
# MaxPool3D_1   [None, 33, 33, 28, 16]
# MaxPool3D_2   [None, 17, 17, 14, 32]
# MaxPool3D_3   [None, 9, 9, 7, 64]
# MaxPool3D_4   [None, 5, 5, 4, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
#
# 2019-03-05 22:28:50.843279: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-05 22:28:50.919529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-05 22:28:50.919899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.23GiB
# 2019-03-05 22:28:50.919913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-05 22:28:51.097448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-05 22:28:51.097474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-05 22:28:51.097479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-05 22:28:51.097635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9886 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: training_loss = 7494902.50 (2.231 sec)
#  (val_loss)test_loss = 2981516.25
# Step 100: training_loss = 731.93 (0.475 sec)
#  (val_loss)test_loss = 6703.18
# Step 200: training_loss = 63865.95 (0.483 sec)
#  (val_loss)test_loss = 53182.90
# Step 300: training_loss = 2457.39 (0.473 sec)
#  (val_loss)test_loss = 6459.66
# Step 400: training_loss = 33791.54 (0.466 sec)
#  (val_loss)test_loss = 8740.79
# Step 500: training_loss = 1886.30 (0.473 sec)
#  (val_loss)test_loss = 2564.95
# Step 600: training_loss = 2656.52 (0.476 sec)
#  (val_loss)test_loss = 3104.27
# Step 700: training_loss = 2253.85 (0.471 sec)
#  (val_loss)test_loss = 1894.96
# Step 800: training_loss = 1809.35 (0.464 sec)
#  (val_loss)test_loss = 4132.34
# Step 900: training_loss = 2170.93 (0.472 sec)
#  (val_loss)test_loss = 1752.95
# Step 1000: training_loss = 1740.30 (0.475 sec)
#  (val_loss)test_loss = 1774.45
# Step 1100: training_loss = 2301.06 (0.485 sec)
#  (val_loss)test_loss = 2691.19
# Step 1200: training_loss = 3045.00 (0.470 sec)
#  (val_loss)test_loss = 3899.98
# Step 1300: training_loss = 1093.60 (0.467 sec)
#  (val_loss)test_loss = 1379.85
# Step 1400: training_loss = 3520.94 (0.466 sec)
#  (val_loss)test_loss = 1519.44
# Step 1500: training_loss = 816.80 (0.481 sec)
#  (val_loss)test_loss = 2046.40
# Step 1600: training_loss = 1087.52 (0.481 sec)
#  (val_loss)test_loss = 1882.73
# Step 1700: training_loss = 1620.36 (0.470 sec)
#  (val_loss)test_loss = 1622.95
# Step 1800: training_loss = 2187.07 (0.477 sec)
#  (val_loss)test_loss = 1927.22
# Step 1900: training_loss = 988.63 (0.472 sec)
#  (val_loss)test_loss = 1552.87
# Step 2000: training_loss = 2057.38 (0.474 sec)
#  (val_loss)test_loss = 1612.64
# Step 2100: training_loss = 1195.94 (0.481 sec)
#  (val_loss)test_loss = 1908.41
# Step 2200: training_loss = 1796.98 (0.468 sec)
#  (val_loss)test_loss = 1394.80
# Step 2300: training_loss = 1173.94 (0.469 sec)
#  (val_loss)test_loss = 1789.19
# Step 2400: training_loss = 1003.54 (0.485 sec)
#  (val_loss)test_loss = 1456.03
# Step 2500: training_loss = 664.47 (0.475 sec)
#  (val_loss)test_loss = 788.31
# Step 2600: training_loss = 897.41 (0.470 sec)
#  (val_loss)test_loss = 973.23
# Step 2700: training_loss = 1465.58 (0.468 sec)
#  (val_loss)test_loss = 2184.36
# Step 2800: training_loss = 1122.05 (0.476 sec)
#  (val_loss)test_loss = 914.04
# Step 2900: training_loss = 1726.58 (0.469 sec)
#  (val_loss)test_loss = 1305.81
# Step 3000: training_loss = 1117.64 (0.469 sec)
#  (val_loss)test_loss = 1459.36
# Step 3100: training_loss = 443.60 (0.462 sec)
#  (val_loss)test_loss = 1284.50
# Step 3200: training_loss = 1437.12 (0.465 sec)
#  (val_loss)test_loss = 1386.12
# Step 3300: training_loss = 1011.89 (0.467 sec)
#  (val_loss)test_loss = 1281.37
# Step 3400: training_loss = 1349.02 (0.486 sec)
#  (val_loss)test_loss = 1226.90
# Step 3500: training_loss = 1162.26 (0.472 sec)
#  (val_loss)test_loss = 1353.63
# Step 3600: training_loss = 1312.94 (0.468 sec)
#  (val_loss)test_loss = 1714.27
# Step 3700: training_loss = 1738.36 (0.467 sec)
#  (val_loss)test_loss = 1375.46
# Step 3800: training_loss = 1287.00 (0.469 sec)
#  (val_loss)test_loss = 1272.01
# Step 3900: training_loss = 1276.78 (0.468 sec)
#  (val_loss)test_loss = 1352.48
# Step 4000: training_loss = 1779.12 (0.475 sec)
#  (val_loss)test_loss = 1343.68
# Step 4100: training_loss = 1848.59 (0.467 sec)
#  (val_loss)test_loss = 1688.99
# Step 4200: training_loss = 857.53 (0.469 sec)
#  (val_loss)test_loss = 1022.35
# Step 4300: training_loss = 1294.62 (0.478 sec)
#  (val_loss)test_loss = 1219.50
# Step 4400: training_loss = 882.61 (0.482 sec)
#  (val_loss)test_loss = 1180.66
# Step 4500: training_loss = 1033.62 (0.483 sec)
#  (val_loss)test_loss = 1352.14
# Step 4600: training_loss = 1358.41 (0.468 sec)
#  (val_loss)test_loss = 1661.28
# Step 4700: training_loss = 1317.87 (0.467 sec)
#  (val_loss)test_loss = 1323.33
# Step 4800: training_loss = 812.51 (0.468 sec)
#  (val_loss)test_loss = 1150.15
# Step 4900: training_loss = 985.01 (0.477 sec)
#  (val_loss)test_loss = 1159.69
# Step 5000: training_loss = 1890.36 (0.471 sec)
#  (val_loss)test_loss = 1231.50
# Step 5100: training_loss = 683.88 (0.468 sec)
#  (val_loss)test_loss = 1138.48
# Step 5200: training_loss = 1190.55 (0.471 sec)
#  (val_loss)test_loss = 1091.40
# Done training for 100 epochs, 5300 steps.
# MaxPool3D   [None, 65, 65, 55, 8]
# MaxPool3D_1   [None, 33, 33, 28, 16]
# MaxPool3D_2   [None, 17, 17, 14, 32]
# MaxPool3D_3   [None, 9, 9, 7, 64]
# MaxPool3D_4   [None, 5, 5, 4, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# 2019-03-05 23:11:34.694014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-05 23:11:34.694046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-05 23:11:34.694051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-05 23:11:34.694055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-05 23:11:34.694138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9886 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Traceback (most recent call last):
#   File "demo_1_2.py", line 358, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/home/woody/vpython/vp3.5.2/lib/python3.5/site-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "demo_1_2.py", line 303, in main
#     run_test()
#   File "demo_1_2.py", line 265, in run_test
#     saver.restore(sess, FLAGS.saver_dir)
#   File "/home/woody/vpython/vp3.5.2/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1530, in restore
#     + compat.as_text(save_path))
# ValueError: The passed save_path is not a valid checkpoint: ./log/demo1.2_ruyi_model.ckpt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from my_tools import *
plt_data_path_name = './img/demo_1_1_pltdata_' + time_now()
if not os.path.exists(plt_data_path_name + '.npy'):
    np.save(plt_data_path_name, np.array([[1,2],[3,4]]))
else:
    print(plt_data_path_name + '.npy exists already.')

# %%
import numpy as np
t = time.strftime?
type(t)
a = np.array([[1,2],[3,4]])
np.save('./test'+t,a)
import os
print(np.log10([1000,2,3]))
print(np.log([1000,2,3]))

# %%
npy_img = np.load('./IXI_npy/origin/IXI012.npy')
print(npy_img.shape)
plt.imshow(npy_img[:,:,60])
# plt.imshow(npy_img[:,60,:])
# plt.imshow(npy_img[60,:,:])

# %%
a = np.random.randint(10,size=(3,3))
b = np.random.randint(10,size=(3,3))
c = np.random.randn(3,3)
print(c)
# a += 1
# print(a)
cc = c.astype(int)
print(cc.dtype)
# print(c)
# print(c)
# c.astype(int)
# preprocess_1('IXI002-Guys-0828-T1.nii.gz')

# %%
10/3

# %%
a = np.random.randint

# %%
phenotypics = pd.read_csv('./phenotypics.csv', sep=',',header=0)
# print(phenotypics)
phenotypics[5:10]

# %%
# !cd /media/woody/Elements/age_data/IXI/IXI-T1/

os.path.exists('/media/woody/Elements/age_data/IXI/IXI-T1/IXI.*-.*-.*-T1\.nii\.gz$')

# %%
import time
from progressbar import *

# for i in range(10):
#     print('\r'+str((i+1)*100.0/10)+'%',end='',flush=True)
#     time.sleep(0.3)
# print('abc')

pbar = ProgressBar().start()
for i in range(10):
    pbar.update(int(i*100/(10-1)))
    time.sleep(0.8)
pbar.finish()

# %%
import time
from progressbar import *
total = 100
def dosomework():
    time.sleep(0.01)
widgets = ['Progress: ',Percentage(), ' ', Bar('>'),' ', Timer(),
      ' ', ETA()]
pbar = ProgressBar(widgets=widgets, maxval=total+100).start()
for i in range(total):
    # do something
    pbar.update(i)
    dosomework()
pbar.finish()

# %%
ProgressBar?

# %%
  
import sys, time  
from progressbar import *  
  
total = 1000  
  
def dosomework():  
    time.sleep(0.01)  
pbar = ProgressBar().start()  
for i in range(1000):  
    pbar.update(int((i / (total - 1)) * 100))  
    dosomework()  
pbar.finish()

# %%
data = xlrd.open_workbook('IXI.xls','rb')
print('工作表名为：'+ data.sheet_names()[0])
table = data.sheets()[0]
nrows = table.nrows
ncols = table.ncols
print('表格行数为%d,列数为%d'%(nrows,ncols))

#输出每一行的值
# for item in range(table.nrows):
#     print(table.row_values(item))

#获取单元格的值
cell_A1 = table.row(0)[0].value
cell_A2 = table.cell(0,0).value
cell_A3 = table.col(0)[0].value

print(cell_A1)
print(cell_A2)
print(cell_A3)
