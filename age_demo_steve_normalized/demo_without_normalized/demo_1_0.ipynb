# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from preprocess import *

# preprocess_main()

# %%
# without mean subtracted data: (121, 145, 121)
# !python demo_1_1.py --num_epochs=200
# Out:
# l1_conv3d/Relu   [None, 121, 145, 121, 16]
# l1_conv3d/max_pool3d   [None, 61, 73, 61, 16]
# l2_conv3d/Relu   [None, 61, 73, 61, 32]
# l2_conv3d/max_pool3d   [None, 31, 37, 31, 32]
# l3_conv3d/Relu   [None, 31, 37, 31, 64]
# l3_conv3d/max_pool3d   [None, 16, 19, 16, 64]
# l4_conv3d/Relu   [None, 16, 19, 16, 64]
# l4_conv3d/max_pool3d   [None, 8, 10, 8, 64]
# l5_conv3d/Relu   [None, 8, 10, 8, 64]
# l5_conv3d/max_pool3d   [None, 4, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-21 23:13:05.366735: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-21 23:13:05.478157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-21 23:13:05.478521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.47GiB
# 2019-03-21 23:13:05.478535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-21 23:13:05.653758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-21 23:13:05.653783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-21 23:13:05.653788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-21 23:13:05.653945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10118 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# 2019-03-21 23:13:06.678021: W tensorflow/core/framework/allocator.cc:113] Allocation of 84917800 exceeds 10% of system memory.
# 2019-03-21 23:13:09.618751: W tensorflow/core/framework/allocator.cc:113] Allocation of 84917800 exceeds 10% of system memory.
# 2019-03-21 23:13:09.985919: W tensorflow/core/framework/allocator.cc:113] Allocation of 84917800 exceeds 10% of system memory.
# 2019-03-21 23:13:10.275534: W tensorflow/core/framework/allocator.cc:113] Allocation of 84917800 exceeds 10% of system memory.
# 2019-03-21 23:13:10.572010: W tensorflow/core/framework/allocator.cc:113] Allocation of 84917800 exceeds 10% of system memory.
# Step 0: training_loss = 5885261.00 (3.800 sec)
#  (val_loss)test_loss = 5517538.00
# Step 100: training_loss = 2112.31 (0.863 sec)
#  (val_loss)test_loss = 2364.04
# Step 200: training_loss = 1176.47 (0.848 sec)
#  (val_loss)test_loss = 2049.65
# Step 300: training_loss = 3398.50 (0.858 sec)
#  (val_loss)test_loss = 1925.10
# Step 400: training_loss = 1154.01 (0.854 sec)
#  (val_loss)test_loss = 1849.25
# Step 500: training_loss = 1670.20 (0.856 sec)
#  (val_loss)test_loss = 1859.28
# Step 600: training_loss = 1470.82 (0.853 sec)
#  (val_loss)test_loss = 1778.69
# Step 700: training_loss = 1306.70 (0.858 sec)
#  (val_loss)test_loss = 1709.31
# Step 800: training_loss = 2039.26 (0.853 sec)
#  (val_loss)test_loss = 1659.84
# Step 900: training_loss = 982.85 (0.857 sec)
#  (val_loss)test_loss = 1630.91
# Step 1000: training_loss = 1802.56 (0.875 sec)
#  (val_loss)test_loss = 1582.45
# Step 1100: training_loss = 1615.56 (0.868 sec)
#  (val_loss)test_loss = 1526.65
# Step 1200: training_loss = 1336.06 (0.852 sec)
#  (val_loss)test_loss = 1491.22
# Step 1300: training_loss = 1184.67 (0.860 sec)
#  (val_loss)test_loss = 1499.54
# Step 1400: training_loss = 1643.25 (0.859 sec)
#  (val_loss)test_loss = 1422.58
# Step 1500: training_loss = 1220.44 (0.858 sec)
#  (val_loss)test_loss = 1402.01
# Step 1600: training_loss = 1064.98 (0.860 sec)
#  (val_loss)test_loss = 1340.49
# Step 1700: training_loss = 552.83 (0.864 sec)
#  (val_loss)test_loss = 1284.63
# Step 1800: training_loss = 1849.61 (0.853 sec)
#  (val_loss)test_loss = 1273.18
# Step 1900: training_loss = 1510.40 (0.860 sec)
#  (val_loss)test_loss = 1244.71
# Step 2000: training_loss = 1805.73 (0.858 sec)
#  (val_loss)test_loss = 1191.44
# Step 2100: training_loss = 752.80 (0.859 sec)
#  (val_loss)test_loss = 1117.92
# Step 2200: training_loss = 1706.14 (0.856 sec)
#  (val_loss)test_loss = 1065.63
# Step 2300: training_loss = 220.41 (0.868 sec)
#  (val_loss)test_loss = 1065.35
# Step 2400: training_loss = 790.98 (0.855 sec)
#  (val_loss)test_loss = 1000.79
# Step 2500: training_loss = 793.88 (0.864 sec)
#  (val_loss)test_loss = 953.74
# Step 2600: training_loss = 419.00 (0.861 sec)
#  (val_loss)test_loss = 965.51
# Step 2700: training_loss = 574.92 (0.859 sec)
#  (val_loss)test_loss = 921.19
# Step 2800: training_loss = 172.33 (0.858 sec)
#  (val_loss)test_loss = 849.93
# Step 2900: training_loss = 827.97 (0.859 sec)
#  (val_loss)test_loss = 829.52
# Step 3000: training_loss = 606.78 (0.858 sec)
#  (val_loss)test_loss = 788.66
# Step 3100: training_loss = 416.96 (0.865 sec)
#  (val_loss)test_loss = 778.62
# Step 3200: training_loss = 990.34 (0.874 sec)
#  (val_loss)test_loss = 725.97
# Step 3300: training_loss = 492.76 (0.858 sec)
#  (val_loss)test_loss = 685.96
# Step 3400: training_loss = 475.42 (0.863 sec)
#  (val_loss)test_loss = 660.43
# Step 3500: training_loss = 527.92 (0.860 sec)
#  (val_loss)test_loss = 641.81
# Step 3600: training_loss = 602.60 (0.854 sec)
#  (val_loss)test_loss = 637.65
# Step 3700: training_loss = 1218.81 (0.861 sec)
#  (val_loss)test_loss = 604.79
# Step 3800: training_loss = 666.56 (0.869 sec)
#  (val_loss)test_loss = 571.11
# Step 3900: training_loss = 934.90 (0.867 sec)
#  (val_loss)test_loss = 555.32
# Step 4000: training_loss = 817.23 (0.858 sec)
#  (val_loss)test_loss = 528.37
# Step 4100: training_loss = 405.74 (0.857 sec)
#  (val_loss)test_loss = 523.49
# Step 4200: training_loss = 400.17 (0.864 sec)
#  (val_loss)test_loss = 507.70
# Step 4300: training_loss = 588.14 (0.861 sec)
#  (val_loss)test_loss = 494.96
# best shot model: test_loss = 494.96, step = 4300
# model saved successfully.
# Step 4400: training_loss = 435.99 (0.861 sec)
#  (val_loss)test_loss = 492.61
# best shot model: test_loss = 492.61, step = 4400
# model saved successfully.
# Step 4500: training_loss = 603.73 (0.860 sec)
#  (val_loss)test_loss = 485.84
# best shot model: test_loss = 485.84, step = 4500
# model saved successfully.
# Step 4600: training_loss = 296.76 (0.862 sec)
#  (val_loss)test_loss = 460.76
# best shot model: test_loss = 460.76, step = 4600
# model saved successfully.
# Step 4700: training_loss = 321.56 (0.856 sec)
#  (val_loss)test_loss = 474.57
# Step 4800: training_loss = 277.09 (0.857 sec)
#  (val_loss)test_loss = 470.72
# Step 4900: training_loss = 348.74 (0.861 sec)
#  (val_loss)test_loss = 459.15
# best shot model: test_loss = 459.15, step = 4900
# model saved successfully.
# Step 5000: training_loss = 637.43 (0.858 sec)
#  (val_loss)test_loss = 450.83
# best shot model: test_loss = 450.83, step = 5000
# model saved successfully.
# Step 5100: training_loss = 551.86 (0.854 sec)
#  (val_loss)test_loss = 448.13
# best shot model: test_loss = 448.13, step = 5100
# model saved successfully.
# Step 5200: training_loss = 576.41 (0.872 sec)
#  (val_loss)test_loss = 448.18
# Step 5300: training_loss = 448.31 (0.850 sec)
#  (val_loss)test_loss = 447.16
# best shot model: test_loss = 447.16, step = 5300
# model saved successfully.
# Step 5400: training_loss = 807.76 (0.858 sec)
#  (val_loss)test_loss = 438.88
# best shot model: test_loss = 438.88, step = 5400
# model saved successfully.
# Step 5500: training_loss = 498.58 (0.861 sec)
#  (val_loss)test_loss = 434.74
# best shot model: test_loss = 434.74, step = 5500
# model saved successfully.
# Step 5600: training_loss = 406.80 (0.857 sec)
#  (val_loss)test_loss = 438.73
# Step 5700: training_loss = 254.98 (0.854 sec)
#  (val_loss)test_loss = 428.21
# best shot model: test_loss = 428.21, step = 5700
# model saved successfully.
# Step 5800: training_loss = 535.71 (0.858 sec)
#  (val_loss)test_loss = 433.41
# Step 5900: training_loss = 680.04 (0.856 sec)
#  (val_loss)test_loss = 442.44
# Step 6000: training_loss = 371.06 (0.853 sec)
#  (val_loss)test_loss = 429.13
# Step 6100: training_loss = 383.84 (0.862 sec)
#  (val_loss)test_loss = 427.28
# best shot model: test_loss = 427.28, step = 6100
# model saved successfully.
# Step 6200: training_loss = 693.75 (0.853 sec)
#  (val_loss)test_loss = 431.17
# Step 6300: training_loss = 367.79 (0.854 sec)
#  (val_loss)test_loss = 421.51
# best shot model: test_loss = 421.51, step = 6300
# model saved successfully.
# Step 6400: training_loss = 553.13 (0.856 sec)
#  (val_loss)test_loss = 423.15
# Step 6500: training_loss = 374.69 (0.858 sec)
#  (val_loss)test_loss = 426.69
# Step 6600: training_loss = 560.85 (0.861 sec)
#  (val_loss)test_loss = 424.65
# Step 6700: training_loss = 354.86 (0.861 sec)
#  (val_loss)test_loss = 424.02
# Step 6800: training_loss = 477.62 (0.857 sec)
#  (val_loss)test_loss = 420.20
# best shot model: test_loss = 420.20, step = 6800
# model saved successfully.
# Step 6900: training_loss = 495.69 (0.855 sec)
#  (val_loss)test_loss = 423.31
# Step 7000: training_loss = 474.91 (0.863 sec)
#  (val_loss)test_loss = 423.54
# Step 7100: training_loss = 447.38 (0.854 sec)
#  (val_loss)test_loss = 435.64
# Step 7200: training_loss = 362.23 (0.854 sec)
#  (val_loss)test_loss = 427.37
# Step 7300: training_loss = 551.63 (0.861 sec)
#  (val_loss)test_loss = 426.32
# Step 7400: training_loss = 263.95 (0.855 sec)
#  (val_loss)test_loss = 424.57
# Step 7500: training_loss = 675.14 (0.858 sec)
#  (val_loss)test_loss = 426.99
# Step 7600: training_loss = 226.04 (0.857 sec)
#  (val_loss)test_loss = 419.84
# best shot model: test_loss = 419.84, step = 7600
# model saved successfully.
# Step 7700: training_loss = 370.91 (0.851 sec)
#  (val_loss)test_loss = 423.06
# Step 7800: training_loss = 809.90 (0.871 sec)
#  (val_loss)test_loss = 425.83
# Step 7900: training_loss = 246.12 (0.858 sec)
#  (val_loss)test_loss = 430.89
# Step 8000: training_loss = 434.94 (0.858 sec)
#  (val_loss)test_loss = 428.21
# Step 8100: training_loss = 462.37 (0.852 sec)
#  (val_loss)test_loss = 432.90
# Step 8200: training_loss = 307.87 (0.855 sec)
#  (val_loss)test_loss = 431.46
# Step 8300: training_loss = 279.60 (0.858 sec)
#  (val_loss)test_loss = 420.84
# Step 8400: training_loss = 204.47 (0.857 sec)
#  (val_loss)test_loss = 423.69
# Step 8500: training_loss = 370.87 (0.854 sec)
#  (val_loss)test_loss = 424.20
# Step 8600: training_loss = 514.48 (0.871 sec)
#  (val_loss)test_loss = 423.39
# Step 8700: training_loss = 265.52 (0.870 sec)
#  (val_loss)test_loss = 426.81
# Step 8800: training_loss = 385.91 (0.854 sec)
#  (val_loss)test_loss = 424.99
# Step 8900: training_loss = 389.86 (0.856 sec)
#  (val_loss)test_loss = 431.69
# Step 9000: training_loss = 425.60 (0.870 sec)
#  (val_loss)test_loss = 425.70
# Step 9100: training_loss = 255.37 (0.866 sec)
#  (val_loss)test_loss = 424.99
# Step 9200: training_loss = 361.34 (0.861 sec)
#  (val_loss)test_loss = 421.69
# Step 9300: training_loss = 503.04 (0.866 sec)
#  (val_loss)test_loss = 419.74
# best shot model: test_loss = 419.74, step = 9300
# model saved successfully.
# Step 9400: training_loss = 477.91 (0.877 sec)
#  (val_loss)test_loss = 422.46
# Step 9500: training_loss = 572.28 (0.867 sec)
#  (val_loss)test_loss = 438.50
# Step 9600: training_loss = 613.05 (0.857 sec)
#  (val_loss)test_loss = 423.51
# Step 9700: training_loss = 362.17 (0.859 sec)
#  (val_loss)test_loss = 424.11
# Done training for 200 epochs, 9740 steps.
# l1_conv3d/Relu   [None, 121, 145, 121, 16]
# l1_conv3d/max_pool3d   [None, 61, 73, 61, 16]
# l2_conv3d/Relu   [None, 61, 73, 61, 32]
# l2_conv3d/max_pool3d   [None, 31, 37, 31, 32]
# l3_conv3d/Relu   [None, 31, 37, 31, 64]
# l3_conv3d/max_pool3d   [None, 16, 19, 16, 64]
# l4_conv3d/Relu   [None, 16, 19, 16, 64]
# l4_conv3d/max_pool3d   [None, 8, 10, 8, 64]
# l5_conv3d/Relu   [None, 8, 10, 8, 64]
# l5_conv3d/max_pool3d   [None, 4, 5, 4, 64]
# l6_fc/fc_out1   [None, 512]
# l6_fc/dropout1/mul   [None, 512]
# l7_fc/fc_out2   [None, 128]
# l7_fc/dropout2/mul   [None, 128]
# l8_fc/final_output   [None, 1]
# 2019-03-22 01:35:15.949188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-22 01:35:15.949221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-22 01:35:15.949227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-22 01:35:15.949231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-22 01:35:15.949312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10118 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model loaded successfully.
# test_loss = 419.74, test_accuracy = 0.00.
# Figure(1500x500)
# Figure(640x480)

# %%
# !python demo_1_2.py --num_epochs=200 --MIN_TEST_LOSS=1000.0
# Out:
# MaxPool3D   [None, 61, 73, 61, 8]
# MaxPool3D_1   [None, 31, 37, 31, 16]
# MaxPool3D_2   [None, 16, 19, 16, 32]
# MaxPool3D_3   [None, 8, 10, 8, 64]
# MaxPool3D_4   [None, 4, 5, 4, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# 2019-03-22 01:35:25.288802: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-22 01:35:25.368903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-22 01:35:25.369286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.40GiB
# 2019-03-22 01:35:25.369299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-22 01:35:25.542124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-22 01:35:25.542152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-22 01:35:25.542157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-22 01:35:25.542312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10051 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Let's get started to train!
# Step 0: training_loss = 99976.34 (2.431 sec)
#  (val_loss)test_loss = 98781.98
# Step 100: training_loss = 1734.49 (0.525 sec)
#  (val_loss)test_loss = 1917.33
# Step 200: training_loss = 540.54 (0.527 sec)
#  (val_loss)test_loss = 1160.64
# Step 300: training_loss = 2188.58 (0.524 sec)
#  (val_loss)test_loss = 1108.08
# Step 400: training_loss = 440.88 (0.530 sec)
#  (val_loss)test_loss = 1035.24
# Step 500: training_loss = 1002.57 (0.536 sec)
#  (val_loss)test_loss = 1009.07
# Step 600: training_loss = 766.70 (0.523 sec)
#  (val_loss)test_loss = 857.39
# best shot model: test_loss = 857.39, step = 600
# model saved successfully.
# Step 700: training_loss = 687.48 (0.522 sec)
#  (val_loss)test_loss = 1116.30
# Step 800: training_loss = 1390.75 (0.531 sec)
#  (val_loss)test_loss = 1061.98
# Step 900: training_loss = 614.67 (0.522 sec)
#  (val_loss)test_loss = 1096.32
# Step 1000: training_loss = 1146.86 (0.536 sec)
#  (val_loss)test_loss = 1070.71
# Step 1100: training_loss = 1078.69 (0.534 sec)
#  (val_loss)test_loss = 1101.01
# Step 1200: training_loss = 1081.21 (0.518 sec)
#  (val_loss)test_loss = 1194.80
# Step 1300: training_loss = 705.21 (0.523 sec)
#  (val_loss)test_loss = 1045.31
# Step 1400: training_loss = 1150.48 (0.526 sec)
#  (val_loss)test_loss = 1001.40
# Step 1500: training_loss = 851.11 (0.528 sec)
#  (val_loss)test_loss = 991.27
# Step 1600: training_loss = 759.21 (0.519 sec)
#  (val_loss)test_loss = 973.69
# Step 1700: training_loss = 422.71 (0.523 sec)
#  (val_loss)test_loss = 972.97
# Step 1800: training_loss = 1691.10 (0.527 sec)
#  (val_loss)test_loss = 1259.90
# Step 1900: training_loss = 1147.05 (0.531 sec)
#  (val_loss)test_loss = 945.22
# Step 2000: training_loss = 1481.42 (0.526 sec)
#  (val_loss)test_loss = 1013.60
# Step 2100: training_loss = 662.17 (0.525 sec)
#  (val_loss)test_loss = 932.20
# Step 2200: training_loss = 1553.07 (0.538 sec)
#  (val_loss)test_loss = 972.11
# Step 2300: training_loss = 204.18 (0.529 sec)
#  (val_loss)test_loss = 918.81
# Step 2400: training_loss = 762.77 (0.526 sec)
#  (val_loss)test_loss = 970.06
# Step 2500: training_loss = 885.49 (0.526 sec)
#  (val_loss)test_loss = 1003.70
# Step 2600: training_loss = 505.38 (0.528 sec)
#  (val_loss)test_loss = 1018.48
# Step 2700: training_loss = 682.48 (0.525 sec)
#  (val_loss)test_loss = 1018.62
# Step 2800: training_loss = 310.74 (0.523 sec)
#  (val_loss)test_loss = 1032.28
# Step 2900: training_loss = 1135.28 (0.524 sec)
#  (val_loss)test_loss = 1025.11
# Step 3000: training_loss = 863.63 (0.527 sec)
#  (val_loss)test_loss = 1083.49
# Step 3100: training_loss = 631.91 (0.526 sec)
#  (val_loss)test_loss = 1026.27
# Step 3200: training_loss = 1385.77 (0.521 sec)
#  (val_loss)test_loss = 1052.66
# Step 3300: training_loss = 740.00 (0.541 sec)
#  (val_loss)test_loss = 973.93
# Step 3400: training_loss = 673.56 (0.549 sec)
#  (val_loss)test_loss = 963.64
# Step 3500: training_loss = 866.95 (0.538 sec)
#  (val_loss)test_loss = 973.94
# Step 3600: training_loss = 889.21 (0.527 sec)
#  (val_loss)test_loss = 970.73
# Step 3700: training_loss = 1677.49 (0.537 sec)
#  (val_loss)test_loss = 923.64
# Step 3800: training_loss = 1136.33 (0.524 sec)
#  (val_loss)test_loss = 944.31
# Step 3900: training_loss = 1571.41 (0.525 sec)
#  (val_loss)test_loss = 920.84
# Step 4000: training_loss = 1290.45 (0.529 sec)
#  (val_loss)test_loss = 899.91
# Step 4100: training_loss = 764.70 (0.522 sec)
#  (val_loss)test_loss = 912.85
# Step 4200: training_loss = 710.66 (0.523 sec)
#  (val_loss)test_loss = 902.05
# Step 4300: training_loss = 1081.62 (0.524 sec)
#  (val_loss)test_loss = 932.48
# Step 4400: training_loss = 823.08 (0.530 sec)
#  (val_loss)test_loss = 956.74
# Step 4500: training_loss = 934.28 (0.526 sec)
#  (val_loss)test_loss = 958.00
# Step 4600: training_loss = 940.78 (0.530 sec)
#  (val_loss)test_loss = 1041.50
# Step 4700: training_loss = 501.14 (0.527 sec)
#  (val_loss)test_loss = 1001.08
# Step 4800: training_loss = 740.37 (0.530 sec)
#  (val_loss)test_loss = 1020.34
# Step 4900: training_loss = 728.89 (0.532 sec)
#  (val_loss)test_loss = 1031.33
# Step 5000: training_loss = 1408.62 (0.534 sec)
#  (val_loss)test_loss = 1014.51
# Step 5100: training_loss = 1141.00 (0.540 sec)
#  (val_loss)test_loss = 982.70
# Step 5200: training_loss = 1040.17 (0.528 sec)
#  (val_loss)test_loss = 977.35
# Step 5300: training_loss = 575.30 (0.524 sec)
#  (val_loss)test_loss = 935.90
# Step 5400: training_loss = 642.76 (0.529 sec)
#  (val_loss)test_loss = 926.60
# Step 5500: training_loss = 1048.65 (0.534 sec)
#  (val_loss)test_loss = 921.24
# Step 5600: training_loss = 974.79 (0.529 sec)
#  (val_loss)test_loss = 929.52
# Step 5700: training_loss = 365.84 (0.522 sec)
#  (val_loss)test_loss = 882.89
# Step 5800: training_loss = 1196.73 (0.534 sec)
#  (val_loss)test_loss = 907.28
# Step 5900: training_loss = 1603.40 (0.524 sec)
#  (val_loss)test_loss = 891.59
# Step 6000: training_loss = 595.92 (0.524 sec)
#  (val_loss)test_loss = 876.45
# Step 6100: training_loss = 676.21 (0.526 sec)
#  (val_loss)test_loss = 860.99
# Step 6200: training_loss = 1333.88 (0.526 sec)
#  (val_loss)test_loss = 885.80
# Step 6300: training_loss = 1037.00 (0.539 sec)
#  (val_loss)test_loss = 922.04
# Step 6400: training_loss = 999.60 (0.525 sec)
#  (val_loss)test_loss = 952.19
# Step 6500: training_loss = 1189.76 (0.528 sec)
#  (val_loss)test_loss = 989.27
# Step 6600: training_loss = 1136.80 (0.543 sec)
#  (val_loss)test_loss = 1005.07
# Step 6700: training_loss = 969.39 (0.522 sec)
#  (val_loss)test_loss = 990.41
# Step 6800: training_loss = 707.86 (0.533 sec)
#  (val_loss)test_loss = 962.33
# Step 6900: training_loss = 1243.85 (0.526 sec)
#  (val_loss)test_loss = 964.63
# Step 7000: training_loss = 1263.62 (0.529 sec)
#  (val_loss)test_loss = 891.27
# Step 7100: training_loss = 938.35 (0.526 sec)
#  (val_loss)test_loss = 878.39
# Step 7200: training_loss = 698.09 (0.528 sec)
#  (val_loss)test_loss = 863.40
# Step 7300: training_loss = 685.23 (0.539 sec)
#  (val_loss)test_loss = 862.51
# Step 7400: training_loss = 596.26 (0.531 sec)
#  (val_loss)test_loss = 865.22
# Step 7500: training_loss = 1530.43 (0.529 sec)
#  (val_loss)test_loss = 897.44
# Step 7600: training_loss = 658.75 (0.525 sec)
#  (val_loss)test_loss = 851.09
# best shot model: test_loss = 851.09, step = 7600
# model saved successfully.
# Step 7700: training_loss = 401.38 (0.532 sec)
#  (val_loss)test_loss = 804.44
# best shot model: test_loss = 804.44, step = 7700
# model saved successfully.
# Step 7800: training_loss = 1714.53 (0.528 sec)
#  (val_loss)test_loss = 759.02
# best shot model: test_loss = 759.02, step = 7800
# model saved successfully.
# Step 7900: training_loss = 308.12 (0.534 sec)
#  (val_loss)test_loss = 772.95
# Step 8000: training_loss = 694.79 (0.535 sec)
#  (val_loss)test_loss = 764.05
# Step 8100: training_loss = 704.00 (0.524 sec)
#  (val_loss)test_loss = 787.18
# Step 8200: training_loss = 497.01 (0.534 sec)
#  (val_loss)test_loss = 832.95
# Step 8300: training_loss = 665.18 (0.522 sec)
#  (val_loss)test_loss = 849.66
# Step 8400: training_loss = 341.55 (0.526 sec)
#  (val_loss)test_loss = 856.86
# Step 8500: training_loss = 1014.75 (0.539 sec)
#  (val_loss)test_loss = 872.80
# Step 8600: training_loss = 895.85 (0.520 sec)
#  (val_loss)test_loss = 854.50
# Step 8700: training_loss = 610.93 (0.526 sec)
#  (val_loss)test_loss = 865.38
# Step 8800: training_loss = 923.16 (0.523 sec)
#  (val_loss)test_loss = 820.52
# Step 8900: training_loss = 682.51 (0.519 sec)
#  (val_loss)test_loss = 777.09
# Step 9000: training_loss = 746.09 (0.532 sec)
#  (val_loss)test_loss = 748.01
# best shot model: test_loss = 748.01, step = 9000
# model saved successfully.
# Step 9100: training_loss = 284.00 (0.525 sec)
#  (val_loss)test_loss = 754.39
# Step 9200: training_loss = 147.73 (0.545 sec)
#  (val_loss)test_loss = 757.69
# Step 9300: training_loss = 1225.33 (0.535 sec)
#  (val_loss)test_loss = 771.18
# Step 9400: training_loss = 1039.71 (0.522 sec)
#  (val_loss)test_loss = 785.67
# Step 9500: training_loss = 1086.93 (0.524 sec)
#  (val_loss)test_loss = 775.23
# Step 9600: training_loss = 751.28 (0.531 sec)
#  (val_loss)test_loss = 724.80
# best shot model: test_loss = 724.80, step = 9600
# model saved successfully.
# Step 9700: training_loss = 790.74 (0.522 sec)
#  (val_loss)test_loss = 694.85
# best shot model: test_loss = 694.85, step = 9700
# model saved successfully.
# Done training for 200 epochs, 9740 steps.
# MaxPool3D   [None, 61, 73, 61, 8]
# MaxPool3D_1   [None, 31, 37, 31, 16]
# MaxPool3D_2   [None, 16, 19, 16, 32]
# MaxPool3D_3   [None, 8, 10, 8, 64]
# MaxPool3D_4   [None, 4, 5, 4, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# 2019-03-22 03:03:00.833294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0
# 2019-03-22 03:03:00.833338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-03-22 03:03:00.833345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0
# 2019-03-22 03:03:00.833349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N
# 2019-03-22 03:03:00.833445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10051 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model loaded successfully.
# test_loss(RMSE) = 694.85.
# Figure(1500x500)
# Figure(640x480)

# %%
gen_tfrecord('./training.csv',npy_dir='./data_npy/origin/',tf_filename='training_without_meansub.tfrecords')
gen_tfrecord('./test.csv',npy_dir='./data_npy/origin/',tf_filename='test_without_meansub.tfrecords')
