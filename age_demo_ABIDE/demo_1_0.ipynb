# %% [markdown]
# ABIDE I

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from preprocess import *
from my_tools import *

# %%
# preprocess_main()

# %%
# !python demo_1_1.py --num_epochs=520

# %%
# !python demo_1_2.py --num_epochs=200 --batch_size=8 --MIN_TEST_LOSS=1000.0 
# !python demo_1_2.py --num_epochs=200 --MIN_TEST_LOSS=1000.0
# Out:
# MaxPool3D   [None, 65, 65, 65, 8]
# MaxPool3D_1   [None, 33, 33, 33, 16]
# MaxPool3D_2   [None, 17, 17, 17, 32]
# MaxPool3D_3   [None, 9, 9, 9, 64]
# MaxPool3D_4   [None, 5, 5, 5, 128]
# dropout_5/mul   [None, 1024]
# output   [None, 1]
# 2019-03-19 18:47:27.588776: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-03-19 18:47:27.686278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-19 18:47:27.686639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.721
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.56GiB
# ...

# %%
img = np.load('./data_npy/origin/50507.npy')
print2d(img)

# %%
np.max(age_list)

# %%
np.min(age_list)

# %%
'./data_npy/mean_subtracted/51075.npy'
