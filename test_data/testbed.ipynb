# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append("..")
from dev_tools.my_tools import *
from dev_tools.model_tools import *

# %%
img_abide = np.load('./50972.npy')
print2d_origin(img_abide)
# Out:
# 0.08146964856230032

# %%
img_ixi = np.load('./IXI002.npy')
print2d_origin(img_ixi)
# Out:
# 0.04124748490945674

# %%
def rot_ixi2abide(img_ixi):
    temp = np.rot90(img_ixi,axes=(1,2))
    temp = np.rot90(temp,axes=(1,0))
    return temp
print2d_origin(rot_ixi2abide(img_ixi))
# Out:
# 0.04124748490945674

# %%
print2d_origin(np.swapaxes(img_ixi,0,1))
# Out:
# 0.04124748490945674

# %%
print2d_origin(np.swapaxes(img_ixi,1,2))
# Out:
# 0.04124748490945674

# %%
print2d_origin(np.rot90(img_ixi,axes=(0,2)))
# Out:
# 0.04124748490945674

# %%
np.rot90?
